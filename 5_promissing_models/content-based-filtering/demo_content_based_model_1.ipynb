# %%
import unicodecsv
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

def read_csv(filename):
    with open(filename, 'rb') as f:
        reader = unicodecsv.DictReader(f)
        return list(reader)

# %% [markdown]
# ### Import Dataframe

# %%
df_product_id = pd.read_csv('model/product_id_md1.csv')
df_product_id.head()
# Out:
#       MATNR    Model         Color         Style            Cat2  Model_id  \
# 0  19047936  Patisia         White       Vintage    ตู้ข้างเตียง      2886
# 1  19045101  Cannery        Yellow        Modern  โซฟา 3 ที่นั่ง       719
# 2  19050282    zNone  Multi-Colour       Vintage         กรอบรูป      8226
# 3  59000365   Meudon         Black  Contemporary      ชุดห้องนอน      2542
# 4  59001810   Alicia         White        Modern      ชุดห้องนอน       295
#
#    Color_id  Style_id  Cat2_id
# 0        16        24       61
# 1        17        12      203
# 2        10        24        5
# 3         1         5       51
# 4        16        12       51

# %% [markdown]
# # Model 1.1 Word Detection

# %% [markdown]
# ### Normal Scale

# %%
from sklearn.neighbors import NearestNeighbors

input_item = 19117034 #ใส่ input(MATNR)
input_index = df_product_id.index[df_product_id['MATNR'] == input_item].tolist()[0]
call_frame = df_product_id.loc[(df_product_id.MATNR.isin([input_item])), ['Color_id', 'Style_id', 'Cat2_id']]
item = call_frame.values

product = df_product_id.iloc[:,6:9].values
nbrs = NearestNeighbors(n_neighbors=11).fit(product)
nbrs_res = nbrs.kneighbors([item[0]])[1]
nbrs_list = nbrs_res.tolist()[0]
while input_index in nbrs_list: nbrs_list.remove(input_index)
result = nbrs_list
#print(result)
df_product_id.iloc[result]
# Out:
#           MATNR    Model  Color   Style                     Cat2  Model_id  \
# 18045  59008084     Hana  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้      1573
# 27545  19132830  Restrol  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้      3021
# 19335  19111488     Zoki  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้      3897
# 12177  19080279    Coupe  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้       933
# 19876  59012560     Zoki  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้      3897
# 7626   19090106   Anakin  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้       348
# 20116  59012554  Restrol  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้      3021
# 19306  59011377     Zoki  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้      3897
# 23021  59012842   Anakin  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้       348
# 27515  19097478   Berska  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้       585
#
#        Color_id  Style_id  Cat2_id
# 18045         1        12      244
# 27545         1        12      244
# 19335         1        12      244
# 12177         1        12      244
# 19876         1        12      244
# 7626          1        12      244
# 20116         1        12      244
# 19306         1        12      244
# 23021         1        12      244
# 27515         1        12      244

# %% [markdown]
# Rescaling (Normalize)

# %%
from sklearn import preprocessing
from sklearn.preprocessing import normalize

color_id_norm = df_product_id[['Color_id']].values
min_max_scaler = preprocessing.MinMaxScaler()
color_scaled = min_max_scaler.fit_transform(color_id_norm)
df_color_norm = pd.DataFrame(color_scaled, columns=['Color_id_n'])

sty_id_norm = df_product_id[['Style_id']].values
min_max_scaler = preprocessing.MinMaxScaler()
sty_scaled = min_max_scaler.fit_transform(sty_id_norm)
df_sty_norm = pd.DataFrame(sty_scaled, columns=['Style_id_n'])

cat2_id_norm = df_product_id[['Cat2_id']].values
min_max_scaler = preprocessing.MinMaxScaler()
cat2_scaled = min_max_scaler.fit_transform(cat2_id_norm)
df_cat2_norm = pd.DataFrame(cat2_scaled, columns=['Cat2_id_n'])

df_product_id_n = pd.concat([df_product_id, df_color_norm, df_sty_norm, df_cat2_norm], axis=1)
df_product_id_n.drop(df_product_id_n.columns[[5,6,7,8]], axis=1, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# # Model 1.2 Word Detection

# %% [markdown]
# ### Rescale

# %%
from sklearn.neighbors import NearestNeighbors

input_item = 19117034 #ใส่ input(MATNR)
input_index = df_product_id_n.index[df_product_id_n['MATNR'] == input_item].tolist()[0]
call_frame = df_product_id_n.loc[(df_product_id_n.MATNR.isin([input_item])), ['Color_id_n', 'Style_id_n', 'Cat2_id_n']]
item = call_frame.values

product = df_product_id_n.iloc[:,5:8].values
nbrs = NearestNeighbors(n_neighbors=11).fit(product)
nbrs_res = nbrs.kneighbors([item[0]])[1]
nbrs_list = nbrs_res.tolist()[0]
while input_index in nbrs_list: nbrs_list.remove(input_index)
result = nbrs_list
#print(result)
df_product_id_n.iloc[result]
# Out:
#           MATNR    Model  Color   Style                     Cat2  Color_id_n  \
# 12177  19080279    Coupe  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 18045  59008084     Hana  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 23021  59012842   Anakin  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 7626   19090106   Anakin  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 19335  19111488     Zoki  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 27515  19097478   Berska  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 27545  19132830  Restrol  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 20116  59012554  Restrol  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 19306  59011377     Zoki  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 19876  59012560     Zoki  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
#
#        Style_id_n  Cat2_id_n
# 12177    0.002539   0.053231
# 18045    0.002539   0.053231
# 23021    0.002539   0.053231
# 7626     0.002539   0.053231
# 19335    0.002539   0.053231
# 27515    0.002539   0.053231
# 27545    0.002539   0.053231
# 20116    0.002539   0.053231
# 19306    0.002539   0.053231
# 19876    0.002539   0.053231

# %% [markdown]
# <b>Check Item</b>

# %%
df_product_id.loc[df_product_id['Cat2'] == 'โต๊ะอาหารขาเหล็กท๊อปไม้' ]
# Out:
#           MATNR    Model         Color                Style  \
# 1009   19108511   Yadira         Brown          Modern Chic
# 2010   19060526    Utano         White      Oriental Aspire
# 2397   19055547   Kuwait          Grey              Ecolism
# 2484   19058360   Baylee          Gold               Modern
# 2634   19066969    Tania          Grey               Modern
# 3803   59002843      Uda  Multi-Colour               Modern
# 5633   19076067    Actor          Grey               Luxury
# 5955   19093947     Coco         Black              Vintage
# 6211   19088113     Fina         Brown               Modern
# 6307   19089770      Ami         Brown           Industrial
# 6801   19090043   Sillon          Grey               Modern
# 7626   19090106   Anakin         Black               Modern
# 7805   59008269    Yoshi         White               Modern
# 7809   59005708   Anakin         White               Modern
# 7879   19097469   Montis          Grey               Modern
# 8302   19112243   Common         Brown              Vintage
# 8445   59008270   Yadira         zNone               Modern
# 8876   19090108   Berska         Black           Industrial
# 9168   19113392   Harare         Brown           Industrial
# 9770   19108509    Yoshi         Brown          Modern Chic
# 11626  19090040    Silla          Grey               Modern
# 11769  19110612     Fido         Brown  Modern Contemporary
# 12177  19080279    Coupe         Black               Modern
# 12562  19100697   Lestro         White               Modern
# 12914  59011511   Gonest          Grey         Contemporary
# 13419  19097336      Gik         White               Modern
# 15225  19100696   Lestro         Brown               Modern
# 15908  19089117   Theola          Grey               Modern
# 16228  19112211    Glass         White               Modern
