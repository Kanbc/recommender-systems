# %%
import unicodecsv
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

def read_csv(filename):
    with open(filename, 'rb') as f:
        reader = unicodecsv.DictReader(f)
        return list(reader)

# %% [markdown]
# ## Import

# %% [markdown]
# ## Product, Style, Model, Color

# %%
product = pd.read_csv('../../2_data/explored/product.csv')
style = pd.read_csv('../../2_data/explored/style.csv')
model = pd.read_csv('../../2_data/explored/md2t_model.csv')
cat2 = pd.read_csv('../../2_data/explored/md4t_cat2.csv')
color = pd.read_csv('../../2_data/explored/md6t_catcolor.csv')

# %%
product.head()
# Out:
#       MATNR                                    MAKTX  DEPT_ID1 MVGR1 MVGR2  \
# 0  19047936             PATISIA/ตู้ข้างเตียงNT45/ขาว       1.0    14   A20
# 1  19045101  โซฟาCANNERY/นต.HE51-12/เหลือง-ลายทาง/3S       3.0    10   059
# 2  19050282               VPกรอบรูป#HD5937A/ไม้ขัดสี       6.0    19
# 3  59000365             Bedroom/Meudon 6'&Isis/Wenge       1.0    14   598
# 4  59001810      Bedroom/ALicia-E 6'&Meudon/White/Re       1.0    14   466
#
#    MVGR3 MVGR4 MVGR5 MVGR6  MVGR7  STY_ID  \
# 0    2.0    70    J9    01    9.0    14.0
# 1   35.0    59    B2    32    8.0     6.0
# 2   51.0    B4          58   23.0    14.0
# 3    2.0    CD    05    D6    9.0     3.0
# 4    2.0    CD    05    01    9.0     6.0
#
#                                               META_K
# 0  SB,KONCEPT FURNITURE,Patisia,ชุดห้องนอน,โต๊ะ/ต...
# 1  SB,SB FURNITURE,Cannery,Sofa Fabric,โซฟา 3 ที่...
# 2     SB,VINTAGE PASSION,,กรอบรูปและภาพแขวน,กรอบรูป,
# 3  SB,เอส.บี,เฟอร์นิเจอร์,KONCEPT FURNITURE,Meudo...
# 4  SB,เอส.บี,เฟอร์นิเจอร์,KONCEPT FURNITURE,Alici...

# %%
product.drop(product.columns[[2,3,5,7,9,11]], axis=1, inplace = True)
product
# Out:
#           MATNR                                     MAKTX MVGR2 MVGR4 MVGR6  \
# 0      19047936              PATISIA/ตู้ข้างเตียงNT45/ขาว   A20    70    01
# 1      19045101   โซฟาCANNERY/นต.HE51-12/เหลือง-ลายทาง/3S   059    59    32
# 2      19050282                VPกรอบรูป#HD5937A/ไม้ขัดสี          B4    58
# 3      59000365              Bedroom/Meudon 6'&Isis/Wenge   598    CD    D6
# 4      59001810       Bedroom/ALicia-E 6'&Meudon/White/Re   466    CD    01
# 5      19049900          โซฟาSANTANA/SLขาวกุ๊นดำ/มุม(ขวา)   HN6    62    01
# 6      19040929  โซฟาBELLA(62-3)/หนังแท้/SL/นต.(ZP-15)/3S   755    59    33
# 7      19045046                    โซฟาJOVI#AS-S077/ดำ/4S   207    60    06
# 8      19045211        GRAZIA I/เตียง5'/E/วอลนัท/เบาะครีม   543    02    37
# 9      59000343        Bedroom/Koloze-B 6'&Foresta/Walnut   576          37
# 10     19042680     โซฟาKOKORO#2(V0910)ผ้าม่วงHE70-29B/3S   226    59    97
# 11     19050326      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/2S   AC9    58    01
# 12     19050327   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/4S   AB4    60    34
# 13     19042726            โซฟาเบดIVES(K04-W)/ผ้าม่วง#U18   181    68    97
# 14     19045832         MAXIO-E/เตียง6'/ขาDดำCHGขาวBL/ขาว   254    02    01
# 15     19050328   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/2S   AB4    58    34
# 16     19050345         ตู้โชว์YITTA#D4200001/ขาว/กระจกใส   BE7    D9    39
# 17     19047934                    PATISIA/ตู้สูงSC90/ขาว   A20    D9    01
# 18     19049891      โซฟาKABIRA#KS1003/ผ้าเทาลาย#JBY-4/2S   Z52    58    34
# 19     19050324          โซฟาLEEWAN#LC-36/SLบรอนซ์เงิน/2S   AC2    58    34
# 20     19050325      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/4S   AC9    60    01
# 21     19045031     โซฟาMAMARA#2หนังแท้-หนังสค.นตB99/ซ้าย   249    64    33
# 22     19045032  โซฟาMAMARA#2หนังแท้-หนังสค.ครีมC004/ซ้าย   249    64    26
# 23     19035030           EXIO/ตู้ผ้าWF139/D05-139/ดำ/ขาว   109    D5    06
# 24     19042705    โซฟาANGELA#S-507ผ้าครีมเงา#C6013-10/3S   746    59    26
# 25     19046676        โซฟาCOCO/แดงเลือดหมู/ลายดอกม่วง/2S   769    58    31
# 26     19049870        TERMINUS/ตู้สูงHC080/เวงเก้/เหลือง   A21    E4    36
# 27     19049871     TERMINUS/ไซด์บอร์ดTV180/เวงเก้/เหลือง   A21    B1    36
# 28     59000712                                **DELETE**   198    A2    01
# 29     59000614            Dining/Hybrid/ครีม&Coqx4/White   551         NaN
# ...         ...                                       ...   ...   ...   ...
# 27542  19138746             โซฟาA-SONIA/น้ำตาล/ผ้าครีม/3S   YQ1    59    33
# 27543  19139148         โซฟาESPANSO/ผ้าลายหนังน้ำตาล-7/3S   YL1    59    33
# 27544  19132025    TRIXIE/เคาน์เตอร์บาร์CB180#2/CLS SMOKE   TL3    45    B3
# 27545  19132830     โต๊ะอาหารRESTROL#2-A240/CLS DARK SHER   TL4    A4    B7
# 27546  19134126                 โซฟา0529/4D/Mimosa/CUS***   XN9    61   NaN
# 27547  19134146               โซฟา0529/4D/Eurosoft/CUS***   XN9    61   NaN
# 27548  19134382            โซฟา0530/4DHMEB/Orvieto/CUS***   XO1    61   NaN
# 27549  19140271                       โซฟาHANLY/ผ้าเทา/3S   YT6    59    34
# 27550  19140411       โต๊ะอาหารXANTIC-A/ดำ/ไม้ELMธรรมชาติ   YT9    A4    53
# 27551  19140588            ตู้โชว์DANTE/โลหะไม้/ดำ+นต.***   YU8    D9    33
# 27552  19140589          ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.***   YU8    B1    33
# 27553  19140590                 ตู้ข้างเตียงDANTE/โลหะ/ดำ   YU8    70    06
# 27554  19140591             ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.   YU8    B1    33
# 27555  19125474               FINETTI/เตียงBCUS5/เวฟ/SR4/   127    02   NaN
# 27556  19135987          โต๊ะอาหารLACEE-A/ไม้ธรรมชาติ/ขาว   YH2    A2    74
# 27557  19131725                โซฟาTAG/SLน้ำตาล/มุม(ซ้าย)   TV9    64    33
# 27558  19135988           เก้าอี้LACEE-B/ผ้าเขียว#G028-38   YH2    27    19
# 27559  19136286  EARRA#3/ตู้สูงCT160+บันได/เหล็กดำ/วีเนีย   MZ4    E4    06
# 27560  19136287        EFFECT#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ5    J5    06
# 27561  19136288         ECONO#4/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ8    J5    06
# 27562  19136289         ENEMA#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   MZ3    J5    06
# 27563  19134398              โซฟา0530/4DHMEB/Marco/CUS***   XO1    61   NaN
# 27564  19134406             โซฟา0530/4DHMEB/Mimosa/CUS***   XO1    61   NaN
# 27565  19134454            โซฟา0530/4DHMEB/Vintage/CUS***   XO1    61   NaN
# 27566  19140598           โซฟาREBECCA#2/กำมะหยี่เหลือง/2S   ST3    58    32
# 27567  19140896         ARMCHAIR/MIRANDA/ผ้ากำมะหยี่เขียว   603    AU    19
# 27568  19141036             โซฟาREBECCA#2/กำมะหยี่ครีม/2S   ST3    61    26
# 27569  19141037            โซฟาREBECCA#2/กำมะหยี่เขียว/2S   ST3    61    19
# 27570  19141038               โซฟาREBECCA#2/ผ้าม่วงSDY/2S   ST3    61    97
# 27571  19141039               โซฟาREBECCA#2/ผ้าเทาดำHC/2S   ST3    61    34
#
#        STY_ID
# 0        14.0
# 1         6.0
# 2        14.0
# 3         3.0
# 4         6.0
# 5         6.0
# 6         9.0
# 7         6.0
# 8         3.0
# 9         6.0
# 10        3.0
# 11        5.0
# 12        5.0
# 13        6.0
# 14        9.0
# 15        5.0
# 16        5.0
# 17       14.0
# 18        8.0
# 19        5.0
# 20        5.0
# 21        6.0
# 22        6.0
# 23        9.0
# 24        7.0
# 25        6.0
# 26        6.0
# 27        6.0
# 28        8.0
# 29        3.0
# ...       ...
# 27542     NaN
# 27543     NaN
# 27544     6.0
# 27545     6.0
# 27546     6.0
# 27547     6.0
# 27548     6.0
# 27549     NaN
# 27550     NaN
# 27551     NaN
# 27552     NaN
# 27553     NaN
# 27554     NaN
# 27555     6.0
# 27556     3.0
# 27557     3.0
# 27558     3.0
# 27559     NaN
# 27560     NaN
# 27561     NaN
# 27562     NaN
# 27563     6.0
# 27564     6.0
# 27565     6.0
# 27566     NaN
# 27567     NaN
# 27568     NaN
# 27569     NaN
# 27570     NaN
# 27571     NaN
#
# [27572 rows x 6 columns]

# %%
color.head()
# Out:
#   NODE                LTEXT        LTEXT_T
# 0   CM  KITCHEN SET KOURMET  ชุดครัวครูเม่
# 1   G6          BRONZE WAVE     บรอนซ์ เวฟ
# 2   G7         COPPER GLOSS  คอปเปอร์ กรอส
# 3   G8               CREAMY        ครีมมี่
# 4   G9            PINK GOLD    พิงก์ โกลด์

# %%
cat2.head()
# Out:
#   NODE             LTEXT         LTEXT_T
# 0   BG         ม่านตาไก่         Pierced
# 1   BH        ม่านหลุยส์          Louise
# 2   BI     ม่านคอกระเช้า            Loop
# 3   BJ         มู่ลี่ไม้    Wooden Blind
# 4   BK  มู่ลี่อลูมิเนียม  Venetian Blind

# %%
style.head()
# Out:
#    STY_ID             STYLE
# 0       1           Artdeco
# 1       2    Colour Passion
# 2       3      Contemporary
# 3       4           Ecolism
# 4       5  Luxury Glamorous

# %%
model.head()
# Out:
#   NODE    LTEXT LTEXT_T
# 0  AW7    Tonio     NaN
# 1  AW8  Toronto     NaN
# 2  AW9   Tritus     NaN
# 3  AX1    Turko     NaN
# 4  AX2   Tycoon     NaN

# %%
model['LTEXT_T'].unique()
# Out:
# array([nan, '0283', 'มาเดอร่า', ..., 'EUR-04-0401', 'มาการิต้า',
#        'ท๊อปเปอร์'], dtype=object)

# %% [markdown]
# # Merge dataframe

# %% [markdown]
# Product + Style

# %%
product_style = pd.merge(product, style,  how='left', left_on=['STY_ID'], right_on = ['STY_ID'])
product_style
# Out:
#           MATNR                                     MAKTX MVGR2 MVGR4 MVGR6  \
# 0      19047936              PATISIA/ตู้ข้างเตียงNT45/ขาว   A20    70    01
# 1      19045101   โซฟาCANNERY/นต.HE51-12/เหลือง-ลายทาง/3S   059    59    32
# 2      19050282                VPกรอบรูป#HD5937A/ไม้ขัดสี          B4    58
# 3      59000365              Bedroom/Meudon 6'&Isis/Wenge   598    CD    D6
# 4      59001810       Bedroom/ALicia-E 6'&Meudon/White/Re   466    CD    01
# 5      19049900          โซฟาSANTANA/SLขาวกุ๊นดำ/มุม(ขวา)   HN6    62    01
# 6      19040929  โซฟาBELLA(62-3)/หนังแท้/SL/นต.(ZP-15)/3S   755    59    33
# 7      19045046                    โซฟาJOVI#AS-S077/ดำ/4S   207    60    06
# 8      19045211        GRAZIA I/เตียง5'/E/วอลนัท/เบาะครีม   543    02    37
# 9      59000343        Bedroom/Koloze-B 6'&Foresta/Walnut   576          37
# 10     19042680     โซฟาKOKORO#2(V0910)ผ้าม่วงHE70-29B/3S   226    59    97
# 11     19050326      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/2S   AC9    58    01
# 12     19050327   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/4S   AB4    60    34
# 13     19042726            โซฟาเบดIVES(K04-W)/ผ้าม่วง#U18   181    68    97
# 14     19045832         MAXIO-E/เตียง6'/ขาDดำCHGขาวBL/ขาว   254    02    01
# 15     19050328   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/2S   AB4    58    34
# 16     19050345         ตู้โชว์YITTA#D4200001/ขาว/กระจกใส   BE7    D9    39
# 17     19047934                    PATISIA/ตู้สูงSC90/ขาว   A20    D9    01
# 18     19049891      โซฟาKABIRA#KS1003/ผ้าเทาลาย#JBY-4/2S   Z52    58    34
# 19     19050324          โซฟาLEEWAN#LC-36/SLบรอนซ์เงิน/2S   AC2    58    34
# 20     19050325      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/4S   AC9    60    01
# 21     19045031     โซฟาMAMARA#2หนังแท้-หนังสค.นตB99/ซ้าย   249    64    33
# 22     19045032  โซฟาMAMARA#2หนังแท้-หนังสค.ครีมC004/ซ้าย   249    64    26
# 23     19035030           EXIO/ตู้ผ้าWF139/D05-139/ดำ/ขาว   109    D5    06
# 24     19042705    โซฟาANGELA#S-507ผ้าครีมเงา#C6013-10/3S   746    59    26
# 25     19046676        โซฟาCOCO/แดงเลือดหมู/ลายดอกม่วง/2S   769    58    31
# 26     19049870        TERMINUS/ตู้สูงHC080/เวงเก้/เหลือง   A21    E4    36
# 27     19049871     TERMINUS/ไซด์บอร์ดTV180/เวงเก้/เหลือง   A21    B1    36
# 28     59000712                                **DELETE**   198    A2    01
# 29     59000614            Dining/Hybrid/ครีม&Coqx4/White   551         NaN
# ...         ...                                       ...   ...   ...   ...
# 27542  19138746             โซฟาA-SONIA/น้ำตาล/ผ้าครีม/3S   YQ1    59    33
# 27543  19139148         โซฟาESPANSO/ผ้าลายหนังน้ำตาล-7/3S   YL1    59    33
# 27544  19132025    TRIXIE/เคาน์เตอร์บาร์CB180#2/CLS SMOKE   TL3    45    B3
# 27545  19132830     โต๊ะอาหารRESTROL#2-A240/CLS DARK SHER   TL4    A4    B7
# 27546  19134126                 โซฟา0529/4D/Mimosa/CUS***   XN9    61   NaN
# 27547  19134146               โซฟา0529/4D/Eurosoft/CUS***   XN9    61   NaN
# 27548  19134382            โซฟา0530/4DHMEB/Orvieto/CUS***   XO1    61   NaN
# 27549  19140271                       โซฟาHANLY/ผ้าเทา/3S   YT6    59    34
# 27550  19140411       โต๊ะอาหารXANTIC-A/ดำ/ไม้ELMธรรมชาติ   YT9    A4    53
# 27551  19140588            ตู้โชว์DANTE/โลหะไม้/ดำ+นต.***   YU8    D9    33
# 27552  19140589          ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.***   YU8    B1    33
# 27553  19140590                 ตู้ข้างเตียงDANTE/โลหะ/ดำ   YU8    70    06
# 27554  19140591             ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.   YU8    B1    33
# 27555  19125474               FINETTI/เตียงBCUS5/เวฟ/SR4/   127    02   NaN
# 27556  19135987          โต๊ะอาหารLACEE-A/ไม้ธรรมชาติ/ขาว   YH2    A2    74
# 27557  19131725                โซฟาTAG/SLน้ำตาล/มุม(ซ้าย)   TV9    64    33
# 27558  19135988           เก้าอี้LACEE-B/ผ้าเขียว#G028-38   YH2    27    19
# 27559  19136286  EARRA#3/ตู้สูงCT160+บันได/เหล็กดำ/วีเนีย   MZ4    E4    06
# 27560  19136287        EFFECT#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ5    J5    06
# 27561  19136288         ECONO#4/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ8    J5    06
# 27562  19136289         ENEMA#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   MZ3    J5    06
# 27563  19134398              โซฟา0530/4DHMEB/Marco/CUS***   XO1    61   NaN
# 27564  19134406             โซฟา0530/4DHMEB/Mimosa/CUS***   XO1    61   NaN
# 27565  19134454            โซฟา0530/4DHMEB/Vintage/CUS***   XO1    61   NaN
# 27566  19140598           โซฟาREBECCA#2/กำมะหยี่เหลือง/2S   ST3    58    32
# 27567  19140896         ARMCHAIR/MIRANDA/ผ้ากำมะหยี่เขียว   603    AU    19
# 27568  19141036             โซฟาREBECCA#2/กำมะหยี่ครีม/2S   ST3    61    26
# 27569  19141037            โซฟาREBECCA#2/กำมะหยี่เขียว/2S   ST3    61    19
# 27570  19141038               โซฟาREBECCA#2/ผ้าม่วงSDY/2S   ST3    61    97
# 27571  19141039               โซฟาREBECCA#2/ผ้าเทาดำHC/2S   ST3    61    34
#
#       STY_ID             STYLE
# 0         14           Vintage
# 1          6            Modern
# 2         14           Vintage
# 3          3      Contemporary
# 4          6            Modern
# 5          6            Modern
# 6          9    Modern Italian
# 7          6            Modern
# 8          3      Contemporary
# 9          6            Modern
# 10         3      Contemporary
# 11         5  Luxury Glamorous
# 12         5  Luxury Glamorous
# 13         6            Modern
# 14         9    Modern Italian
# 15         5  Luxury Glamorous
# 16         5  Luxury Glamorous
# 17        14           Vintage
# 18         8    Modern Classic
# 19         5  Luxury Glamorous
# 20         5  Luxury Glamorous
# 21         6            Modern
# 22         6            Modern
# 23         9    Modern Italian
# 24         7       Modern Chic
# 25         6            Modern
# 26         6            Modern
# 27         6            Modern
# 28         8    Modern Classic
# 29         3      Contemporary
# ...      ...               ...
# 27542    NaN               NaN
# 27543    NaN               NaN
# 27544      6            Modern
# 27545      6            Modern
# 27546      6            Modern
# 27547      6            Modern
# 27548      6            Modern
# 27549    NaN               NaN
# 27550    NaN               NaN
# 27551    NaN               NaN
# 27552    NaN               NaN
# 27553    NaN               NaN
# 27554    NaN               NaN
# 27555      6            Modern
# 27556      3      Contemporary
# 27557      3      Contemporary
# 27558      3      Contemporary
# 27559    NaN               NaN
# 27560    NaN               NaN
# 27561    NaN               NaN
# 27562    NaN               NaN
# 27563      6            Modern
# 27564      6            Modern
# 27565      6            Modern
# 27566    NaN               NaN
# 27567    NaN               NaN
# 27568    NaN               NaN
# 27569    NaN               NaN
# 27570    NaN               NaN
# 27571    NaN               NaN
#
# [27572 rows x 7 columns]

# %% [markdown]
# Product_Style + Model

# %%
product_style_model = pd.merge(product_style, model,  how='left', left_on=['MVGR2'], right_on = ['NODE'])
product_style_model
# Out:
#           MATNR                                     MAKTX MVGR2 MVGR4 MVGR6  \
# 0      19047936              PATISIA/ตู้ข้างเตียงNT45/ขาว   A20    70    01
# 1      19045101   โซฟาCANNERY/นต.HE51-12/เหลือง-ลายทาง/3S   059    59    32
# 2      19050282                VPกรอบรูป#HD5937A/ไม้ขัดสี          B4    58
# 3      59000365              Bedroom/Meudon 6'&Isis/Wenge   598    CD    D6
# 4      59001810       Bedroom/ALicia-E 6'&Meudon/White/Re   466    CD    01
# 5      19049900          โซฟาSANTANA/SLขาวกุ๊นดำ/มุม(ขวา)   HN6    62    01
# 6      19040929  โซฟาBELLA(62-3)/หนังแท้/SL/นต.(ZP-15)/3S   755    59    33
# 7      19045046                    โซฟาJOVI#AS-S077/ดำ/4S   207    60    06
# 8      19045211        GRAZIA I/เตียง5'/E/วอลนัท/เบาะครีม   543    02    37
# 9      59000343        Bedroom/Koloze-B 6'&Foresta/Walnut   576          37
# 10     19042680     โซฟาKOKORO#2(V0910)ผ้าม่วงHE70-29B/3S   226    59    97
# 11     19050326      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/2S   AC9    58    01
# 12     19050327   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/4S   AB4    60    34
# 13     19042726            โซฟาเบดIVES(K04-W)/ผ้าม่วง#U18   181    68    97
# 14     19045832         MAXIO-E/เตียง6'/ขาDดำCHGขาวBL/ขาว   254    02    01
# 15     19050328   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/2S   AB4    58    34
# 16     19050345         ตู้โชว์YITTA#D4200001/ขาว/กระจกใส   BE7    D9    39
# 17     19047934                    PATISIA/ตู้สูงSC90/ขาว   A20    D9    01
# 18     19049891      โซฟาKABIRA#KS1003/ผ้าเทาลาย#JBY-4/2S   Z52    58    34
# 19     19050324          โซฟาLEEWAN#LC-36/SLบรอนซ์เงิน/2S   AC2    58    34
# 20     19050325      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/4S   AC9    60    01
# 21     19045031     โซฟาMAMARA#2หนังแท้-หนังสค.นตB99/ซ้าย   249    64    33
# 22     19045032  โซฟาMAMARA#2หนังแท้-หนังสค.ครีมC004/ซ้าย   249    64    26
# 23     19035030           EXIO/ตู้ผ้าWF139/D05-139/ดำ/ขาว   109    D5    06
# 24     19042705    โซฟาANGELA#S-507ผ้าครีมเงา#C6013-10/3S   746    59    26
# 25     19046676        โซฟาCOCO/แดงเลือดหมู/ลายดอกม่วง/2S   769    58    31
# 26     19049870        TERMINUS/ตู้สูงHC080/เวงเก้/เหลือง   A21    E4    36
# 27     19049871     TERMINUS/ไซด์บอร์ดTV180/เวงเก้/เหลือง   A21    B1    36
# 28     59000712                                **DELETE**   198    A2    01
# 29     59000614            Dining/Hybrid/ครีม&Coqx4/White   551         NaN
# ...         ...                                       ...   ...   ...   ...
# 27542  19138746             โซฟาA-SONIA/น้ำตาล/ผ้าครีม/3S   YQ1    59    33
# 27543  19139148         โซฟาESPANSO/ผ้าลายหนังน้ำตาล-7/3S   YL1    59    33
# 27544  19132025    TRIXIE/เคาน์เตอร์บาร์CB180#2/CLS SMOKE   TL3    45    B3
# 27545  19132830     โต๊ะอาหารRESTROL#2-A240/CLS DARK SHER   TL4    A4    B7
# 27546  19134126                 โซฟา0529/4D/Mimosa/CUS***   XN9    61   NaN
# 27547  19134146               โซฟา0529/4D/Eurosoft/CUS***   XN9    61   NaN
# 27548  19134382            โซฟา0530/4DHMEB/Orvieto/CUS***   XO1    61   NaN
# 27549  19140271                       โซฟาHANLY/ผ้าเทา/3S   YT6    59    34
# 27550  19140411       โต๊ะอาหารXANTIC-A/ดำ/ไม้ELMธรรมชาติ   YT9    A4    53
# 27551  19140588            ตู้โชว์DANTE/โลหะไม้/ดำ+นต.***   YU8    D9    33
# 27552  19140589          ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.***   YU8    B1    33
# 27553  19140590                 ตู้ข้างเตียงDANTE/โลหะ/ดำ   YU8    70    06
# 27554  19140591             ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.   YU8    B1    33
# 27555  19125474               FINETTI/เตียงBCUS5/เวฟ/SR4/   127    02   NaN
# 27556  19135987          โต๊ะอาหารLACEE-A/ไม้ธรรมชาติ/ขาว   YH2    A2    74
# 27557  19131725                โซฟาTAG/SLน้ำตาล/มุม(ซ้าย)   TV9    64    33
# 27558  19135988           เก้าอี้LACEE-B/ผ้าเขียว#G028-38   YH2    27    19
# 27559  19136286  EARRA#3/ตู้สูงCT160+บันได/เหล็กดำ/วีเนีย   MZ4    E4    06
# 27560  19136287        EFFECT#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ5    J5    06
# 27561  19136288         ECONO#4/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ8    J5    06
# 27562  19136289         ENEMA#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   MZ3    J5    06
# 27563  19134398              โซฟา0530/4DHMEB/Marco/CUS***   XO1    61   NaN
# 27564  19134406             โซฟา0530/4DHMEB/Mimosa/CUS***   XO1    61   NaN
# 27565  19134454            โซฟา0530/4DHMEB/Vintage/CUS***   XO1    61   NaN
# 27566  19140598           โซฟาREBECCA#2/กำมะหยี่เหลือง/2S   ST3    58    32
# 27567  19140896         ARMCHAIR/MIRANDA/ผ้ากำมะหยี่เขียว   603    AU    19
# 27568  19141036             โซฟาREBECCA#2/กำมะหยี่ครีม/2S   ST3    61    26
# 27569  19141037            โซฟาREBECCA#2/กำมะหยี่เขียว/2S   ST3    61    19
# 27570  19141038               โซฟาREBECCA#2/ผ้าม่วงSDY/2S   ST3    61    97
# 27571  19141039               โซฟาREBECCA#2/ผ้าเทาดำHC/2S   ST3    61    34
#
#       STY_ID             STYLE NODE     LTEXT    LTEXT_T
# 0         14           Vintage  A20   Patisia        NaN
# 1          6            Modern  059   Cannery        NaN
# 2         14           Vintage  NaN       NaN        NaN
# 3          3      Contemporary  598    Meudon        NaN
# 4          6            Modern  466    Alicia        NaN
# 5          6            Modern  HN6   Santana        NaN
# 6          9    Modern Italian  755     Bella        NaN
# 7          6            Modern  207      Jovi        NaN
# 8          3      Contemporary  543    Grazia        NaN
# 9          6            Modern  576    Koloze        NaN
# 10         3      Contemporary  226    Kokoro        NaN
# 11         5  Luxury Glamorous  AC9    Levonn        NaN
# 12         5  Luxury Glamorous  AB4   Latanya        NaN
# 13         6            Modern  181      Ives        NaN
# 14         9    Modern Italian  254     Maxio        NaN
# 15         5  Luxury Glamorous  AB4   Latanya        NaN
# 16         5  Luxury Glamorous  BE7     Yitta        NaN
# 17        14           Vintage  A20   Patisia        NaN
# 18         8    Modern Classic  Z52    Kabira        NaN
# 19         5  Luxury Glamorous  AC2    Leewan        NaN
# 20         5  Luxury Glamorous  AC9    Levonn        NaN
# 21         6            Modern  249    Mamara        NaN
# 22         6            Modern  249    Mamara        NaN
# 23         9    Modern Italian  109      Exio        NaN
# 24         7       Modern Chic  746    Angela        NaN
# 25         6            Modern  769      Coco        NaN
# 26         6            Modern  A21  Terminus        NaN
# 27         6            Modern  A21  Terminus        NaN
# 28         8    Modern Classic  198   Jocasta        NaN
# 29         3      Contemporary  551    Hybrid        NaN
# ...      ...               ...  ...       ...        ...
# 27542    NaN               NaN  YQ1   A-Sonia  เอ-โซเนีย
# 27543    NaN               NaN  YL1   Espanso    Espanso
# 27544      6            Modern  TL3    Trixie    ทริคซี่
# 27545      6            Modern  TL4   Restrol    เรสโทร์
# 27546      6            Modern  XN9      0529       0529
# 27547      6            Modern  XN9      0529       0529
# 27548      6            Modern  XO1      0530       0530
# 27549    NaN               NaN  YT6     Hanly     เฮนรี่
# 27550    NaN               NaN  YT9    Xantic     ซานติก
# 27551    NaN               NaN  YU8     Dante     แดนเต้
# 27552    NaN               NaN  YU8     Dante     แดนเต้
# 27553    NaN               NaN  YU8     Dante     แดนเต้
# 27554    NaN               NaN  YU8     Dante     แดนเต้
# 27555      6            Modern  127   Finetti        NaN
# 27556      3      Contemporary  YH2     Lacee      ลาเซ่
# 27557      3      Contemporary  TV9       Tag       แท็ก
# 27558      3      Contemporary  YH2     Lacee      ลาเซ่
# 27559    NaN               NaN  MZ4     Earra        NaN
# 27560    NaN               NaN  FJ5    Effect        NaN
# 27561    NaN               NaN  FJ8     Econo        NaN
# 27562    NaN               NaN  MZ3     Enema        NaN
# 27563      6            Modern  XO1      0530       0530
# 27564      6            Modern  XO1      0530       0530
# 27565      6            Modern  XO1      0530       0530
# 27566    NaN               NaN  ST3   Rebecca   รีเบกก้า
# 27567    NaN               NaN  603    Mirada        NaN
# 27568    NaN               NaN  ST3   Rebecca   รีเบกก้า
# 27569    NaN               NaN  ST3   Rebecca   รีเบกก้า
# 27570    NaN               NaN  ST3   Rebecca   รีเบกก้า
# 27571    NaN               NaN  ST3   Rebecca   รีเบกก้า
#
# [27572 rows x 10 columns]

# %% [markdown]
# Product_style_model + Color

# %%
product_style_model_color = pd.merge(product_style_model, color,  how='left', left_on=['MVGR6'], right_on = ['NODE'])
product_style_model_color
# Out:
#           MATNR                                     MAKTX MVGR2 MVGR4 MVGR6  \
# 0      19047936              PATISIA/ตู้ข้างเตียงNT45/ขาว   A20    70    01
# 1      19045101   โซฟาCANNERY/นต.HE51-12/เหลือง-ลายทาง/3S   059    59    32
# 2      19050282                VPกรอบรูป#HD5937A/ไม้ขัดสี          B4    58
# 3      59000365              Bedroom/Meudon 6'&Isis/Wenge   598    CD    D6
# 4      59001810       Bedroom/ALicia-E 6'&Meudon/White/Re   466    CD    01
# 5      19049900          โซฟาSANTANA/SLขาวกุ๊นดำ/มุม(ขวา)   HN6    62    01
# 6      19040929  โซฟาBELLA(62-3)/หนังแท้/SL/นต.(ZP-15)/3S   755    59    33
# 7      19045046                    โซฟาJOVI#AS-S077/ดำ/4S   207    60    06
# 8      19045211        GRAZIA I/เตียง5'/E/วอลนัท/เบาะครีม   543    02    37
# 9      59000343        Bedroom/Koloze-B 6'&Foresta/Walnut   576          37
# 10     19042680     โซฟาKOKORO#2(V0910)ผ้าม่วงHE70-29B/3S   226    59    97
# 11     19050326      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/2S   AC9    58    01
# 12     19050327   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/4S   AB4    60    34
# 13     19042726            โซฟาเบดIVES(K04-W)/ผ้าม่วง#U18   181    68    97
# 14     19045832         MAXIO-E/เตียง6'/ขาDดำCHGขาวBL/ขาว   254    02    01
# 15     19050328   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/2S   AB4    58    34
# 16     19050345         ตู้โชว์YITTA#D4200001/ขาว/กระจกใส   BE7    D9    39
# 17     19047934                    PATISIA/ตู้สูงSC90/ขาว   A20    D9    01
# 18     19049891      โซฟาKABIRA#KS1003/ผ้าเทาลาย#JBY-4/2S   Z52    58    34
# 19     19050324          โซฟาLEEWAN#LC-36/SLบรอนซ์เงิน/2S   AC2    58    34
# 20     19050325      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/4S   AC9    60    01
# 21     19045031     โซฟาMAMARA#2หนังแท้-หนังสค.นตB99/ซ้าย   249    64    33
# 22     19045032  โซฟาMAMARA#2หนังแท้-หนังสค.ครีมC004/ซ้าย   249    64    26
# 23     19035030           EXIO/ตู้ผ้าWF139/D05-139/ดำ/ขาว   109    D5    06
# 24     19042705    โซฟาANGELA#S-507ผ้าครีมเงา#C6013-10/3S   746    59    26
# 25     19046676        โซฟาCOCO/แดงเลือดหมู/ลายดอกม่วง/2S   769    58    31
# 26     19049870        TERMINUS/ตู้สูงHC080/เวงเก้/เหลือง   A21    E4    36
# 27     19049871     TERMINUS/ไซด์บอร์ดTV180/เวงเก้/เหลือง   A21    B1    36
# 28     59000712                                **DELETE**   198    A2    01
# 29     59000614            Dining/Hybrid/ครีม&Coqx4/White   551         NaN
# ...         ...                                       ...   ...   ...   ...
# 27542  19138746             โซฟาA-SONIA/น้ำตาล/ผ้าครีม/3S   YQ1    59    33
# 27543  19139148         โซฟาESPANSO/ผ้าลายหนังน้ำตาล-7/3S   YL1    59    33
# 27544  19132025    TRIXIE/เคาน์เตอร์บาร์CB180#2/CLS SMOKE   TL3    45    B3
# 27545  19132830     โต๊ะอาหารRESTROL#2-A240/CLS DARK SHER   TL4    A4    B7
# 27546  19134126                 โซฟา0529/4D/Mimosa/CUS***   XN9    61   NaN
# 27547  19134146               โซฟา0529/4D/Eurosoft/CUS***   XN9    61   NaN
# 27548  19134382            โซฟา0530/4DHMEB/Orvieto/CUS***   XO1    61   NaN
# 27549  19140271                       โซฟาHANLY/ผ้าเทา/3S   YT6    59    34
# 27550  19140411       โต๊ะอาหารXANTIC-A/ดำ/ไม้ELMธรรมชาติ   YT9    A4    53
# 27551  19140588            ตู้โชว์DANTE/โลหะไม้/ดำ+นต.***   YU8    D9    33
# 27552  19140589          ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.***   YU8    B1    33
# 27553  19140590                 ตู้ข้างเตียงDANTE/โลหะ/ดำ   YU8    70    06
# 27554  19140591             ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.   YU8    B1    33
# 27555  19125474               FINETTI/เตียงBCUS5/เวฟ/SR4/   127    02   NaN
# 27556  19135987          โต๊ะอาหารLACEE-A/ไม้ธรรมชาติ/ขาว   YH2    A2    74
# 27557  19131725                โซฟาTAG/SLน้ำตาล/มุม(ซ้าย)   TV9    64    33
# 27558  19135988           เก้าอี้LACEE-B/ผ้าเขียว#G028-38   YH2    27    19
# 27559  19136286  EARRA#3/ตู้สูงCT160+บันได/เหล็กดำ/วีเนีย   MZ4    E4    06
# 27560  19136287        EFFECT#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ5    J5    06
# 27561  19136288         ECONO#4/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ8    J5    06
# 27562  19136289         ENEMA#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   MZ3    J5    06
# 27563  19134398              โซฟา0530/4DHMEB/Marco/CUS***   XO1    61   NaN
# 27564  19134406             โซฟา0530/4DHMEB/Mimosa/CUS***   XO1    61   NaN
# 27565  19134454            โซฟา0530/4DHMEB/Vintage/CUS***   XO1    61   NaN
# 27566  19140598           โซฟาREBECCA#2/กำมะหยี่เหลือง/2S   ST3    58    32
# 27567  19140896         ARMCHAIR/MIRANDA/ผ้ากำมะหยี่เขียว   603    AU    19
# 27568  19141036             โซฟาREBECCA#2/กำมะหยี่ครีม/2S   ST3    61    26
# 27569  19141037            โซฟาREBECCA#2/กำมะหยี่เขียว/2S   ST3    61    19
# 27570  19141038               โซฟาREBECCA#2/ผ้าม่วงSDY/2S   ST3    61    97
# 27571  19141039               โซฟาREBECCA#2/ผ้าเทาดำHC/2S   ST3    61    34
#
#       STY_ID             STYLE NODE_x   LTEXT_x  LTEXT_T_x NODE_y  \
# 0         14           Vintage    A20   Patisia        NaN     01
# 1          6            Modern    059   Cannery        NaN     32
# 2         14           Vintage    NaN       NaN        NaN     58
# 3          3      Contemporary    598    Meudon        NaN     D6
# 4          6            Modern    466    Alicia        NaN     01
# 5          6            Modern    HN6   Santana        NaN     01
# 6          9    Modern Italian    755     Bella        NaN     33
# 7          6            Modern    207      Jovi        NaN     06
# 8          3      Contemporary    543    Grazia        NaN     37
# 9          6            Modern    576    Koloze        NaN     37
# 10         3      Contemporary    226    Kokoro        NaN     97
# 11         5  Luxury Glamorous    AC9    Levonn        NaN     01
# 12         5  Luxury Glamorous    AB4   Latanya        NaN     34
# 13         6            Modern    181      Ives        NaN     97
# 14         9    Modern Italian    254     Maxio        NaN     01
# 15         5  Luxury Glamorous    AB4   Latanya        NaN     34
# 16         5  Luxury Glamorous    BE7     Yitta        NaN     39
# 17        14           Vintage    A20   Patisia        NaN     01
# 18         8    Modern Classic    Z52    Kabira        NaN     34
# 19         5  Luxury Glamorous    AC2    Leewan        NaN     34
# 20         5  Luxury Glamorous    AC9    Levonn        NaN     01
# 21         6            Modern    249    Mamara        NaN     33
# 22         6            Modern    249    Mamara        NaN     26
# 23         9    Modern Italian    109      Exio        NaN     06
# 24         7       Modern Chic    746    Angela        NaN     26
# 25         6            Modern    769      Coco        NaN     31
# 26         6            Modern    A21  Terminus        NaN     36
# 27         6            Modern    A21  Terminus        NaN     36
# 28         8    Modern Classic    198   Jocasta        NaN     01
# 29         3      Contemporary    551    Hybrid        NaN    NaN
# ...      ...               ...    ...       ...        ...    ...
# 27542    NaN               NaN    YQ1   A-Sonia  เอ-โซเนีย     33
# 27543    NaN               NaN    YL1   Espanso    Espanso     33
# 27544      6            Modern    TL3    Trixie    ทริคซี่     B3
# 27545      6            Modern    TL4   Restrol    เรสโทร์     B7
# 27546      6            Modern    XN9      0529       0529    NaN
# 27547      6            Modern    XN9      0529       0529    NaN
# 27548      6            Modern    XO1      0530       0530    NaN
# 27549    NaN               NaN    YT6     Hanly     เฮนรี่     34
# 27550    NaN               NaN    YT9    Xantic     ซานติก     53
# 27551    NaN               NaN    YU8     Dante     แดนเต้     33
# 27552    NaN               NaN    YU8     Dante     แดนเต้     33
# 27553    NaN               NaN    YU8     Dante     แดนเต้     06
# 27554    NaN               NaN    YU8     Dante     แดนเต้     33
# 27555      6            Modern    127   Finetti        NaN    NaN
# 27556      3      Contemporary    YH2     Lacee      ลาเซ่     74
# 27557      3      Contemporary    TV9       Tag       แท็ก     33
# 27558      3      Contemporary    YH2     Lacee      ลาเซ่     19
# 27559    NaN               NaN    MZ4     Earra        NaN     06
# 27560    NaN               NaN    FJ5    Effect        NaN     06
# 27561    NaN               NaN    FJ8     Econo        NaN     06
# 27562    NaN               NaN    MZ3     Enema        NaN     06
# 27563      6            Modern    XO1      0530       0530    NaN
# 27564      6            Modern    XO1      0530       0530    NaN
# 27565      6            Modern    XO1      0530       0530    NaN
# 27566    NaN               NaN    ST3   Rebecca   รีเบกก้า     32
# 27567    NaN               NaN    603    Mirada        NaN     19
# 27568    NaN               NaN    ST3   Rebecca   รีเบกก้า     26
# 27569    NaN               NaN    ST3   Rebecca   รีเบกก้า     19
# 27570    NaN               NaN    ST3   Rebecca   รีเบกก้า     97
# 27571    NaN               NaN    ST3   Rebecca   รีเบกก้า     34
#
#              LTEXT_y        LTEXT_T_y
# 0              WHITE              ขาว
# 1             YELLOW           เหลือง
# 2       MULTI-COLOUR    มัลติคัลเลอร์
# 3         DARK SHADE        โทนสีเข้ม
# 4              WHITE              ขาว
# 5              WHITE              ขาว
# 6              BROWN           น้ำตาล
# 7              BLACK               ดำ
# 8             WALNUT           วอลนัท
# 9             WALNUT           วอลนัท
# 10            VIOLET          ไวโอแลต
# 11             WHITE              ขาว
# 12              GREY              เทา
# 13            VIOLET          ไวโอแลต
# 14             WHITE              ขาว
# 15              GREY              เทา
# 16           CROMIUM         โครเมียม
# 17             WHITE              ขาว
# 18              GREY              เทา
# 19              GREY              เทา
# 20             WHITE              ขาว
# 21             BROWN           น้ำตาล
# 22             CREAM             ครีม
# 23             BLACK               ดำ
# 24             CREAM             ครีม
# 25               RED              แดง
# 26             WENGE           เวงเก้
# 27             WENGE           เวงเก้
# 28             WHITE              ขาว
# 29               NaN              NaN
# ...              ...              ...
# 27542          BROWN           น้ำตาล
# 27543          BROWN           น้ำตาล
# 27544   SMOKE TIMBER    สโมค ทิมเบอร์
# 27545  DARK SHERWOOD  ดาร์ค เชอร์วู้ด
# 27546            NaN              NaN
# 27547            NaN              NaN
# 27548            NaN              NaN
# 27549           GREY              เทา
# 27550        NATURAL       เนเชอร์รอล
# 27551          BROWN           น้ำตาล
# 27552          BROWN           น้ำตาล
# 27553          BLACK               ดำ
# 27554          BROWN           น้ำตาล
# 27555            NaN              NaN
# 27556   NATURAL WOOD  เนเชอร์รอล วู้ด
# 27557          BROWN           น้ำตาล
# 27558          GREEN            เขียว
# 27559          BLACK               ดำ
# 27560          BLACK               ดำ
# 27561          BLACK               ดำ
# 27562          BLACK               ดำ
# 27563            NaN              NaN
# 27564            NaN              NaN
# 27565            NaN              NaN
# 27566         YELLOW           เหลือง
# 27567          GREEN            เขียว
# 27568          CREAM             ครีม
# 27569          GREEN            เขียว
# 27570         VIOLET          ไวโอแลต
# 27571           GREY              เทา
#
# [27572 rows x 13 columns]

# %%
product_style_model_color_cat2 = pd.merge(product_style_model_color, cat2,  how='left', left_on=['MVGR4'], right_on = ['NODE'])
product_style_model_color_cat2
# Out:
#           MATNR                                     MAKTX MVGR2 MVGR4 MVGR6  \
# 0      19047936              PATISIA/ตู้ข้างเตียงNT45/ขาว   A20    70    01
# 1      19045101   โซฟาCANNERY/นต.HE51-12/เหลือง-ลายทาง/3S   059    59    32
# 2      19050282                VPกรอบรูป#HD5937A/ไม้ขัดสี          B4    58
# 3      59000365              Bedroom/Meudon 6'&Isis/Wenge   598    CD    D6
# 4      59001810       Bedroom/ALicia-E 6'&Meudon/White/Re   466    CD    01
# 5      19049900          โซฟาSANTANA/SLขาวกุ๊นดำ/มุม(ขวา)   HN6    62    01
# 6      19040929  โซฟาBELLA(62-3)/หนังแท้/SL/นต.(ZP-15)/3S   755    59    33
# 7      19045046                    โซฟาJOVI#AS-S077/ดำ/4S   207    60    06
# 8      19045211        GRAZIA I/เตียง5'/E/วอลนัท/เบาะครีม   543    02    37
# 9      59000343        Bedroom/Koloze-B 6'&Foresta/Walnut   576          37
# 10     19042680     โซฟาKOKORO#2(V0910)ผ้าม่วงHE70-29B/3S   226    59    97
# 11     19050326      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/2S   AC9    58    01
# 12     19050327   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/4S   AB4    60    34
# 13     19042726            โซฟาเบดIVES(K04-W)/ผ้าม่วง#U18   181    68    97
# 14     19045832         MAXIO-E/เตียง6'/ขาDดำCHGขาวBL/ขาว   254    02    01
# 15     19050328   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/2S   AB4    58    34
# 16     19050345         ตู้โชว์YITTA#D4200001/ขาว/กระจกใส   BE7    D9    39
# 17     19047934                    PATISIA/ตู้สูงSC90/ขาว   A20    D9    01
# 18     19049891      โซฟาKABIRA#KS1003/ผ้าเทาลาย#JBY-4/2S   Z52    58    34
# 19     19050324          โซฟาLEEWAN#LC-36/SLบรอนซ์เงิน/2S   AC2    58    34
# 20     19050325      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/4S   AC9    60    01
# 21     19045031     โซฟาMAMARA#2หนังแท้-หนังสค.นตB99/ซ้าย   249    64    33
# 22     19045032  โซฟาMAMARA#2หนังแท้-หนังสค.ครีมC004/ซ้าย   249    64    26
# 23     19035030           EXIO/ตู้ผ้าWF139/D05-139/ดำ/ขาว   109    D5    06
# 24     19042705    โซฟาANGELA#S-507ผ้าครีมเงา#C6013-10/3S   746    59    26
# 25     19046676        โซฟาCOCO/แดงเลือดหมู/ลายดอกม่วง/2S   769    58    31
# 26     19049870        TERMINUS/ตู้สูงHC080/เวงเก้/เหลือง   A21    E4    36
# 27     19049871     TERMINUS/ไซด์บอร์ดTV180/เวงเก้/เหลือง   A21    B1    36
# 28     59000712                                **DELETE**   198    A2    01
# 29     59000614            Dining/Hybrid/ครีม&Coqx4/White   551         NaN
# ...         ...                                       ...   ...   ...   ...
# 27542  19138746             โซฟาA-SONIA/น้ำตาล/ผ้าครีม/3S   YQ1    59    33
# 27543  19139148         โซฟาESPANSO/ผ้าลายหนังน้ำตาล-7/3S   YL1    59    33
# 27544  19132025    TRIXIE/เคาน์เตอร์บาร์CB180#2/CLS SMOKE   TL3    45    B3
# 27545  19132830     โต๊ะอาหารRESTROL#2-A240/CLS DARK SHER   TL4    A4    B7
# 27546  19134126                 โซฟา0529/4D/Mimosa/CUS***   XN9    61   NaN
# 27547  19134146               โซฟา0529/4D/Eurosoft/CUS***   XN9    61   NaN
# 27548  19134382            โซฟา0530/4DHMEB/Orvieto/CUS***   XO1    61   NaN
# 27549  19140271                       โซฟาHANLY/ผ้าเทา/3S   YT6    59    34
# 27550  19140411       โต๊ะอาหารXANTIC-A/ดำ/ไม้ELMธรรมชาติ   YT9    A4    53
# 27551  19140588            ตู้โชว์DANTE/โลหะไม้/ดำ+นต.***   YU8    D9    33
# 27552  19140589          ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.***   YU8    B1    33
# 27553  19140590                 ตู้ข้างเตียงDANTE/โลหะ/ดำ   YU8    70    06
# 27554  19140591             ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.   YU8    B1    33
# 27555  19125474               FINETTI/เตียงBCUS5/เวฟ/SR4/   127    02   NaN
# 27556  19135987          โต๊ะอาหารLACEE-A/ไม้ธรรมชาติ/ขาว   YH2    A2    74
# 27557  19131725                โซฟาTAG/SLน้ำตาล/มุม(ซ้าย)   TV9    64    33
# 27558  19135988           เก้าอี้LACEE-B/ผ้าเขียว#G028-38   YH2    27    19
# 27559  19136286  EARRA#3/ตู้สูงCT160+บันได/เหล็กดำ/วีเนีย   MZ4    E4    06
# 27560  19136287        EFFECT#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ5    J5    06
# 27561  19136288         ECONO#4/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ8    J5    06
# 27562  19136289         ENEMA#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   MZ3    J5    06
# 27563  19134398              โซฟา0530/4DHMEB/Marco/CUS***   XO1    61   NaN
# 27564  19134406             โซฟา0530/4DHMEB/Mimosa/CUS***   XO1    61   NaN
# 27565  19134454            โซฟา0530/4DHMEB/Vintage/CUS***   XO1    61   NaN
# 27566  19140598           โซฟาREBECCA#2/กำมะหยี่เหลือง/2S   ST3    58    32
# 27567  19140896         ARMCHAIR/MIRANDA/ผ้ากำมะหยี่เขียว   603    AU    19
# 27568  19141036             โซฟาREBECCA#2/กำมะหยี่ครีม/2S   ST3    61    26
# 27569  19141037            โซฟาREBECCA#2/กำมะหยี่เขียว/2S   ST3    61    19
# 27570  19141038               โซฟาREBECCA#2/ผ้าม่วงSDY/2S   ST3    61    97
# 27571  19141039               โซฟาREBECCA#2/ผ้าเทาดำHC/2S   ST3    61    34
#
#       STY_ID             STYLE NODE_x   LTEXT_x  LTEXT_T_x NODE_y  \
# 0         14           Vintage    A20   Patisia        NaN     01
# 1          6            Modern    059   Cannery        NaN     32
# 2         14           Vintage    NaN       NaN        NaN     58
# 3          3      Contemporary    598    Meudon        NaN     D6
# 4          6            Modern    466    Alicia        NaN     01
# 5          6            Modern    HN6   Santana        NaN     01
# 6          9    Modern Italian    755     Bella        NaN     33
# 7          6            Modern    207      Jovi        NaN     06
# 8          3      Contemporary    543    Grazia        NaN     37
# 9          6            Modern    576    Koloze        NaN     37
# 10         3      Contemporary    226    Kokoro        NaN     97
# 11         5  Luxury Glamorous    AC9    Levonn        NaN     01
# 12         5  Luxury Glamorous    AB4   Latanya        NaN     34
# 13         6            Modern    181      Ives        NaN     97
# 14         9    Modern Italian    254     Maxio        NaN     01
# 15         5  Luxury Glamorous    AB4   Latanya        NaN     34
# 16         5  Luxury Glamorous    BE7     Yitta        NaN     39
# 17        14           Vintage    A20   Patisia        NaN     01
# 18         8    Modern Classic    Z52    Kabira        NaN     34
# 19         5  Luxury Glamorous    AC2    Leewan        NaN     34
# 20         5  Luxury Glamorous    AC9    Levonn        NaN     01
# 21         6            Modern    249    Mamara        NaN     33
# 22         6            Modern    249    Mamara        NaN     26
# 23         9    Modern Italian    109      Exio        NaN     06
# 24         7       Modern Chic    746    Angela        NaN     26
# 25         6            Modern    769      Coco        NaN     31
# 26         6            Modern    A21  Terminus        NaN     36
# 27         6            Modern    A21  Terminus        NaN     36
# 28         8    Modern Classic    198   Jocasta        NaN     01
# 29         3      Contemporary    551    Hybrid        NaN    NaN
# ...      ...               ...    ...       ...        ...    ...
# 27542    NaN               NaN    YQ1   A-Sonia  เอ-โซเนีย     33
# 27543    NaN               NaN    YL1   Espanso    Espanso     33
# 27544      6            Modern    TL3    Trixie    ทริคซี่     B3
# 27545      6            Modern    TL4   Restrol    เรสโทร์     B7
# 27546      6            Modern    XN9      0529       0529    NaN
# 27547      6            Modern    XN9      0529       0529    NaN
# 27548      6            Modern    XO1      0530       0530    NaN
# 27549    NaN               NaN    YT6     Hanly     เฮนรี่     34
# 27550    NaN               NaN    YT9    Xantic     ซานติก     53
# 27551    NaN               NaN    YU8     Dante     แดนเต้     33
# 27552    NaN               NaN    YU8     Dante     แดนเต้     33
# 27553    NaN               NaN    YU8     Dante     แดนเต้     06
# 27554    NaN               NaN    YU8     Dante     แดนเต้     33
# 27555      6            Modern    127   Finetti        NaN    NaN
# 27556      3      Contemporary    YH2     Lacee      ลาเซ่     74
# 27557      3      Contemporary    TV9       Tag       แท็ก     33
# 27558      3      Contemporary    YH2     Lacee      ลาเซ่     19
# 27559    NaN               NaN    MZ4     Earra        NaN     06
# 27560    NaN               NaN    FJ5    Effect        NaN     06
# 27561    NaN               NaN    FJ8     Econo        NaN     06
# 27562    NaN               NaN    MZ3     Enema        NaN     06
# 27563      6            Modern    XO1      0530       0530    NaN
# 27564      6            Modern    XO1      0530       0530    NaN
# 27565      6            Modern    XO1      0530       0530    NaN
# 27566    NaN               NaN    ST3   Rebecca   รีเบกก้า     32
# 27567    NaN               NaN    603    Mirada        NaN     19
# 27568    NaN               NaN    ST3   Rebecca   รีเบกก้า     26
# 27569    NaN               NaN    ST3   Rebecca   รีเบกก้า     19
# 27570    NaN               NaN    ST3   Rebecca   รีเบกก้า     97
# 27571    NaN               NaN    ST3   Rebecca   รีเบกก้า     34
#
#              LTEXT_y        LTEXT_T_y NODE                    LTEXT  \
# 0              WHITE              ขาว   70             ตู้ข้างเตียง
# 1             YELLOW           เหลือง   59           โซฟา 3 ที่นั่ง
# 2       MULTI-COLOUR    มัลติคัลเลอร์   B4                  กรอบรูป
# 3         DARK SHADE        โทนสีเข้ม   CD               ชุดห้องนอน
# 4              WHITE              ขาว   CD               ชุดห้องนอน
# 5              WHITE              ขาว   62           โซฟาเข้ามุมขวา
# 6              BROWN           น้ำตาล   59           โซฟา 3 ที่นั่ง
# 7              BLACK               ดำ   60           โซฟา 4 ที่นั่ง
# 8             WALNUT           วอลนัท   02                    เตียง
# 9             WALNUT           วอลนัท  NaN                      NaN
# 10            VIOLET          ไวโอแลต   59           โซฟา 3 ที่นั่ง
# 11             WHITE              ขาว   58           โซฟา 2 ที่นั่ง
# 12              GREY              เทา   60           โซฟา 4 ที่นั่ง
# 13            VIOLET          ไวโอแลต   68                  โซฟาเบด
# 14             WHITE              ขาว   02                    เตียง
# 15              GREY              เทา   58           โซฟา 2 ที่นั่ง
# 16           CROMIUM         โครเมียม   D9                  ตู้โชว์
# 17             WHITE              ขาว   D9                  ตู้โชว์
# 18              GREY              เทา   58           โซฟา 2 ที่นั่ง
# 19              GREY              เทา   58           โซฟา 2 ที่นั่ง
# 20             WHITE              ขาว   60           โซฟา 4 ที่นั่ง
# 21             BROWN           น้ำตาล   64          โซฟาเข้ามุมซ้าย
# 22             CREAM             ครีม   64          โซฟาเข้ามุมซ้าย
# 23             BLACK               ดำ   D5     ตู้เสื้อผ้าบานเฟี้ยม
# 24             CREAM             ครีม   59           โซฟา 3 ที่นั่ง
# 25               RED              แดง   58           โซฟา 2 ที่นั่ง
# 26             WENGE           เวงเก้   E4                   ตู้สูง
# 27             WENGE           เวงเก้   B1                ไซด์บอร์ด
# 28             WHITE              ขาว   A2         โต๊ะอาหารไม้ล้วน
# 29               NaN              NaN  NaN                      NaN
# ...              ...              ...  ...                      ...
# 27542          BROWN           น้ำตาล   59           โซฟา 3 ที่นั่ง
# 27543          BROWN           น้ำตาล   59           โซฟา 3 ที่นั่ง
# 27544   SMOKE TIMBER    สโมค ทิมเบอร์   45           เคาน์เตอร์บาร์
# 27545  DARK SHERWOOD  ดาร์ค เชอร์วู้ด   A4  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27546            NaN              NaN   61               โซฟาสั่งทำ
# 27547            NaN              NaN   61               โซฟาสั่งทำ
# 27548            NaN              NaN   61               โซฟาสั่งทำ
# 27549           GREY              เทา   59           โซฟา 3 ที่นั่ง
# 27550        NATURAL       เนเชอร์รอล   A4  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27551          BROWN           น้ำตาล   D9                  ตู้โชว์
# 27552          BROWN           น้ำตาล   B1                ไซด์บอร์ด
# 27553          BLACK               ดำ   70             ตู้ข้างเตียง
# 27554          BROWN           น้ำตาล   B1                ไซด์บอร์ด
# 27555            NaN              NaN   02                    เตียง
# 27556   NATURAL WOOD  เนเชอร์รอล วู้ด   A2         โต๊ะอาหารไม้ล้วน
# 27557          BROWN           น้ำตาล   64          โซฟาเข้ามุมซ้าย
# 27558          GREEN            เขียว   27      เก้าอี้เหล็กเบาะผ้า
# 27559          BLACK               ดำ   E4                   ตู้สูง
# 27560          BLACK               ดำ   J5                 ชั้นโล่ง
# 27561          BLACK               ดำ   J5                 ชั้นโล่ง
# 27562          BLACK               ดำ   J5                 ชั้นโล่ง
# 27563            NaN              NaN   61               โซฟาสั่งทำ
# 27564            NaN              NaN   61               โซฟาสั่งทำ
# 27565            NaN              NaN   61               โซฟาสั่งทำ
# 27566         YELLOW           เหลือง   58           โซฟา 2 ที่นั่ง
# 27567          GREEN            เขียว   AU             อาร์มแชร์ผ้า
# 27568          CREAM             ครีม   61               โซฟาสั่งทำ
# 27569          GREEN            เขียว   61               โซฟาสั่งทำ
# 27570         VIOLET          ไวโอแลต   61               โซฟาสั่งทำ
# 27571           GREY              เทา   61               โซฟาสั่งทำ
#
#                  LTEXT_T
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3            Bedroom Set
# 4            Bedroom Set
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28     Dining Table/Wood
# 29                   NaN
# ...                  ...
# 27542                NaN
# 27543                NaN
# 27544                NaN
# 27545                NaN
# 27546                NaN
# 27547                NaN
# 27548                NaN
# 27549                NaN
# 27550                NaN
# 27551                NaN
# 27552                NaN
# 27553                NaN
# 27554                NaN
# 27555                NaN
# 27556  Dining Table/Wood
# 27557                NaN
# 27558                NaN
# 27559                NaN
# 27560                NaN
# 27561                NaN
# 27562                NaN
# 27563                NaN
# 27564                NaN
# 27565                NaN
# 27566                NaN
# 27567                NaN
# 27568                NaN
# 27569                NaN
# 27570                NaN
# 27571                NaN
#
# [27572 rows x 16 columns]

# %% [markdown]
# Change Column Name

# %%
product_style_model_color_cat2.rename(columns={'NODE_x': 'Node_model', 'LTEXT_x': 'Model', 'LTEXT_T_x': 'Model_T', 'NODE_y': 'Node_Color', 'LTEXT_y': 'Color', 'LTEXT_T_y': 'Color_T','STYLE': 'Style', 'NODE' : 'Node_Cat2', 'LTEXT': 'Cat2'}, inplace=True)

# %%
product_merge = product_style_model_color_cat2
product_merge
# Out:
#           MATNR                                     MAKTX MVGR2 MVGR4 MVGR6  \
# 0      19047936              PATISIA/ตู้ข้างเตียงNT45/ขาว   A20    70    01
# 1      19045101   โซฟาCANNERY/นต.HE51-12/เหลือง-ลายทาง/3S   059    59    32
# 2      19050282                VPกรอบรูป#HD5937A/ไม้ขัดสี          B4    58
# 3      59000365              Bedroom/Meudon 6'&Isis/Wenge   598    CD    D6
# 4      59001810       Bedroom/ALicia-E 6'&Meudon/White/Re   466    CD    01
# 5      19049900          โซฟาSANTANA/SLขาวกุ๊นดำ/มุม(ขวา)   HN6    62    01
# 6      19040929  โซฟาBELLA(62-3)/หนังแท้/SL/นต.(ZP-15)/3S   755    59    33
# 7      19045046                    โซฟาJOVI#AS-S077/ดำ/4S   207    60    06
# 8      19045211        GRAZIA I/เตียง5'/E/วอลนัท/เบาะครีม   543    02    37
# 9      59000343        Bedroom/Koloze-B 6'&Foresta/Walnut   576          37
# 10     19042680     โซฟาKOKORO#2(V0910)ผ้าม่วงHE70-29B/3S   226    59    97
# 11     19050326      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/2S   AC9    58    01
# 12     19050327   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/4S   AB4    60    34
# 13     19042726            โซฟาเบดIVES(K04-W)/ผ้าม่วง#U18   181    68    97
# 14     19045832         MAXIO-E/เตียง6'/ขาDดำCHGขาวBL/ขาว   254    02    01
# 15     19050328   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/2S   AB4    58    34
# 16     19050345         ตู้โชว์YITTA#D4200001/ขาว/กระจกใส   BE7    D9    39
# 17     19047934                    PATISIA/ตู้สูงSC90/ขาว   A20    D9    01
# 18     19049891      โซฟาKABIRA#KS1003/ผ้าเทาลาย#JBY-4/2S   Z52    58    34
# 19     19050324          โซฟาLEEWAN#LC-36/SLบรอนซ์เงิน/2S   AC2    58    34
# 20     19050325      โซฟาLEVONN#LC-091101/หนังแท้สีขาว/4S   AC9    60    01
# 21     19045031     โซฟาMAMARA#2หนังแท้-หนังสค.นตB99/ซ้าย   249    64    33
# 22     19045032  โซฟาMAMARA#2หนังแท้-หนังสค.ครีมC004/ซ้าย   249    64    26
# 23     19035030           EXIO/ตู้ผ้าWF139/D05-139/ดำ/ขาว   109    D5    06
# 24     19042705    โซฟาANGELA#S-507ผ้าครีมเงา#C6013-10/3S   746    59    26
# 25     19046676        โซฟาCOCO/แดงเลือดหมู/ลายดอกม่วง/2S   769    58    31
# 26     19049870        TERMINUS/ตู้สูงHC080/เวงเก้/เหลือง   A21    E4    36
# 27     19049871     TERMINUS/ไซด์บอร์ดTV180/เวงเก้/เหลือง   A21    B1    36
# 28     59000712                                **DELETE**   198    A2    01
# 29     59000614            Dining/Hybrid/ครีม&Coqx4/White   551         NaN
# ...         ...                                       ...   ...   ...   ...
# 27542  19138746             โซฟาA-SONIA/น้ำตาล/ผ้าครีม/3S   YQ1    59    33
# 27543  19139148         โซฟาESPANSO/ผ้าลายหนังน้ำตาล-7/3S   YL1    59    33
# 27544  19132025    TRIXIE/เคาน์เตอร์บาร์CB180#2/CLS SMOKE   TL3    45    B3
# 27545  19132830     โต๊ะอาหารRESTROL#2-A240/CLS DARK SHER   TL4    A4    B7
# 27546  19134126                 โซฟา0529/4D/Mimosa/CUS***   XN9    61   NaN
# 27547  19134146               โซฟา0529/4D/Eurosoft/CUS***   XN9    61   NaN
# 27548  19134382            โซฟา0530/4DHMEB/Orvieto/CUS***   XO1    61   NaN
# 27549  19140271                       โซฟาHANLY/ผ้าเทา/3S   YT6    59    34
# 27550  19140411       โต๊ะอาหารXANTIC-A/ดำ/ไม้ELMธรรมชาติ   YT9    A4    53
# 27551  19140588            ตู้โชว์DANTE/โลหะไม้/ดำ+นต.***   YU8    D9    33
# 27552  19140589          ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.***   YU8    B1    33
# 27553  19140590                 ตู้ข้างเตียงDANTE/โลหะ/ดำ   YU8    70    06
# 27554  19140591             ไซด์บอร์ดDANTE/โลหะไม้/ดำ+นต.   YU8    B1    33
# 27555  19125474               FINETTI/เตียงBCUS5/เวฟ/SR4/   127    02   NaN
# 27556  19135987          โต๊ะอาหารLACEE-A/ไม้ธรรมชาติ/ขาว   YH2    A2    74
# 27557  19131725                โซฟาTAG/SLน้ำตาล/มุม(ซ้าย)   TV9    64    33
# 27558  19135988           เก้าอี้LACEE-B/ผ้าเขียว#G028-38   YH2    27    19
# 27559  19136286  EARRA#3/ตู้สูงCT160+บันได/เหล็กดำ/วีเนีย   MZ4    E4    06
# 27560  19136287        EFFECT#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ5    J5    06
# 27561  19136288         ECONO#4/ชั้นโล่ง/เหล็กดำ/วีเนียร์   FJ8    J5    06
# 27562  19136289         ENEMA#3/ชั้นโล่ง/เหล็กดำ/วีเนียร์   MZ3    J5    06
# 27563  19134398              โซฟา0530/4DHMEB/Marco/CUS***   XO1    61   NaN
# 27564  19134406             โซฟา0530/4DHMEB/Mimosa/CUS***   XO1    61   NaN
# 27565  19134454            โซฟา0530/4DHMEB/Vintage/CUS***   XO1    61   NaN
# 27566  19140598           โซฟาREBECCA#2/กำมะหยี่เหลือง/2S   ST3    58    32
# 27567  19140896         ARMCHAIR/MIRANDA/ผ้ากำมะหยี่เขียว   603    AU    19
# 27568  19141036             โซฟาREBECCA#2/กำมะหยี่ครีม/2S   ST3    61    26
# 27569  19141037            โซฟาREBECCA#2/กำมะหยี่เขียว/2S   ST3    61    19
# 27570  19141038               โซฟาREBECCA#2/ผ้าม่วงSDY/2S   ST3    61    97
# 27571  19141039               โซฟาREBECCA#2/ผ้าเทาดำHC/2S   ST3    61    34
#
#       STY_ID             Style Node_model     Model    Model_T Node_Color  \
# 0         14           Vintage        A20   Patisia        NaN         01
# 1          6            Modern        059   Cannery        NaN         32
# 2         14           Vintage        NaN       NaN        NaN         58
# 3          3      Contemporary        598    Meudon        NaN         D6
# 4          6            Modern        466    Alicia        NaN         01
# 5          6            Modern        HN6   Santana        NaN         01
# 6          9    Modern Italian        755     Bella        NaN         33
# 7          6            Modern        207      Jovi        NaN         06
# 8          3      Contemporary        543    Grazia        NaN         37
# 9          6            Modern        576    Koloze        NaN         37
# 10         3      Contemporary        226    Kokoro        NaN         97
# 11         5  Luxury Glamorous        AC9    Levonn        NaN         01
# 12         5  Luxury Glamorous        AB4   Latanya        NaN         34
# 13         6            Modern        181      Ives        NaN         97
# 14         9    Modern Italian        254     Maxio        NaN         01
# 15         5  Luxury Glamorous        AB4   Latanya        NaN         34
# 16         5  Luxury Glamorous        BE7     Yitta        NaN         39
# 17        14           Vintage        A20   Patisia        NaN         01
# 18         8    Modern Classic        Z52    Kabira        NaN         34
# 19         5  Luxury Glamorous        AC2    Leewan        NaN         34
# 20         5  Luxury Glamorous        AC9    Levonn        NaN         01
# 21         6            Modern        249    Mamara        NaN         33
# 22         6            Modern        249    Mamara        NaN         26
# 23         9    Modern Italian        109      Exio        NaN         06
# 24         7       Modern Chic        746    Angela        NaN         26
# 25         6            Modern        769      Coco        NaN         31
# 26         6            Modern        A21  Terminus        NaN         36
# 27         6            Modern        A21  Terminus        NaN         36
# 28         8    Modern Classic        198   Jocasta        NaN         01
# 29         3      Contemporary        551    Hybrid        NaN        NaN
# ...      ...               ...        ...       ...        ...        ...
# 27542    NaN               NaN        YQ1   A-Sonia  เอ-โซเนีย         33
# 27543    NaN               NaN        YL1   Espanso    Espanso         33
# 27544      6            Modern        TL3    Trixie    ทริคซี่         B3
# 27545      6            Modern        TL4   Restrol    เรสโทร์         B7
# 27546      6            Modern        XN9      0529       0529        NaN
# 27547      6            Modern        XN9      0529       0529        NaN
# 27548      6            Modern        XO1      0530       0530        NaN
# 27549    NaN               NaN        YT6     Hanly     เฮนรี่         34
# 27550    NaN               NaN        YT9    Xantic     ซานติก         53
# 27551    NaN               NaN        YU8     Dante     แดนเต้         33
# 27552    NaN               NaN        YU8     Dante     แดนเต้         33
# 27553    NaN               NaN        YU8     Dante     แดนเต้         06
# 27554    NaN               NaN        YU8     Dante     แดนเต้         33
# 27555      6            Modern        127   Finetti        NaN        NaN
# 27556      3      Contemporary        YH2     Lacee      ลาเซ่         74
# 27557      3      Contemporary        TV9       Tag       แท็ก         33
# 27558      3      Contemporary        YH2     Lacee      ลาเซ่         19
# 27559    NaN               NaN        MZ4     Earra        NaN         06
# 27560    NaN               NaN        FJ5    Effect        NaN         06
# 27561    NaN               NaN        FJ8     Econo        NaN         06
# 27562    NaN               NaN        MZ3     Enema        NaN         06
# 27563      6            Modern        XO1      0530       0530        NaN
# 27564      6            Modern        XO1      0530       0530        NaN
# 27565      6            Modern        XO1      0530       0530        NaN
# 27566    NaN               NaN        ST3   Rebecca   รีเบกก้า         32
# 27567    NaN               NaN        603    Mirada        NaN         19
# 27568    NaN               NaN        ST3   Rebecca   รีเบกก้า         26
# 27569    NaN               NaN        ST3   Rebecca   รีเบกก้า         19
# 27570    NaN               NaN        ST3   Rebecca   รีเบกก้า         97
# 27571    NaN               NaN        ST3   Rebecca   รีเบกก้า         34
#
#                Color          Color_T Node_Cat2                     Cat2  \
# 0              WHITE              ขาว        70             ตู้ข้างเตียง
# 1             YELLOW           เหลือง        59           โซฟา 3 ที่นั่ง
# 2       MULTI-COLOUR    มัลติคัลเลอร์        B4                  กรอบรูป
# 3         DARK SHADE        โทนสีเข้ม        CD               ชุดห้องนอน
# 4              WHITE              ขาว        CD               ชุดห้องนอน
# 5              WHITE              ขาว        62           โซฟาเข้ามุมขวา
# 6              BROWN           น้ำตาล        59           โซฟา 3 ที่นั่ง
# 7              BLACK               ดำ        60           โซฟา 4 ที่นั่ง
# 8             WALNUT           วอลนัท        02                    เตียง
# 9             WALNUT           วอลนัท       NaN                      NaN
# 10            VIOLET          ไวโอแลต        59           โซฟา 3 ที่นั่ง
# 11             WHITE              ขาว        58           โซฟา 2 ที่นั่ง
# 12              GREY              เทา        60           โซฟา 4 ที่นั่ง
# 13            VIOLET          ไวโอแลต        68                  โซฟาเบด
# 14             WHITE              ขาว        02                    เตียง
# 15              GREY              เทา        58           โซฟา 2 ที่นั่ง
# 16           CROMIUM         โครเมียม        D9                  ตู้โชว์
# 17             WHITE              ขาว        D9                  ตู้โชว์
# 18              GREY              เทา        58           โซฟา 2 ที่นั่ง
# 19              GREY              เทา        58           โซฟา 2 ที่นั่ง
# 20             WHITE              ขาว        60           โซฟา 4 ที่นั่ง
# 21             BROWN           น้ำตาล        64          โซฟาเข้ามุมซ้าย
# 22             CREAM             ครีม        64          โซฟาเข้ามุมซ้าย
# 23             BLACK               ดำ        D5     ตู้เสื้อผ้าบานเฟี้ยม
# 24             CREAM             ครีม        59           โซฟา 3 ที่นั่ง
# 25               RED              แดง        58           โซฟา 2 ที่นั่ง
# 26             WENGE           เวงเก้        E4                   ตู้สูง
# 27             WENGE           เวงเก้        B1                ไซด์บอร์ด
# 28             WHITE              ขาว        A2         โต๊ะอาหารไม้ล้วน
# 29               NaN              NaN       NaN                      NaN
# ...              ...              ...       ...                      ...
# 27542          BROWN           น้ำตาล        59           โซฟา 3 ที่นั่ง
# 27543          BROWN           น้ำตาล        59           โซฟา 3 ที่นั่ง
# 27544   SMOKE TIMBER    สโมค ทิมเบอร์        45           เคาน์เตอร์บาร์
# 27545  DARK SHERWOOD  ดาร์ค เชอร์วู้ด        A4  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27546            NaN              NaN        61               โซฟาสั่งทำ
# 27547            NaN              NaN        61               โซฟาสั่งทำ
# 27548            NaN              NaN        61               โซฟาสั่งทำ
# 27549           GREY              เทา        59           โซฟา 3 ที่นั่ง
# 27550        NATURAL       เนเชอร์รอล        A4  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27551          BROWN           น้ำตาล        D9                  ตู้โชว์
# 27552          BROWN           น้ำตาล        B1                ไซด์บอร์ด
# 27553          BLACK               ดำ        70             ตู้ข้างเตียง
# 27554          BROWN           น้ำตาล        B1                ไซด์บอร์ด
# 27555            NaN              NaN        02                    เตียง
# 27556   NATURAL WOOD  เนเชอร์รอล วู้ด        A2         โต๊ะอาหารไม้ล้วน
# 27557          BROWN           น้ำตาล        64          โซฟาเข้ามุมซ้าย
# 27558          GREEN            เขียว        27      เก้าอี้เหล็กเบาะผ้า
# 27559          BLACK               ดำ        E4                   ตู้สูง
# 27560          BLACK               ดำ        J5                 ชั้นโล่ง
# 27561          BLACK               ดำ        J5                 ชั้นโล่ง
# 27562          BLACK               ดำ        J5                 ชั้นโล่ง
# 27563            NaN              NaN        61               โซฟาสั่งทำ
# 27564            NaN              NaN        61               โซฟาสั่งทำ
# 27565            NaN              NaN        61               โซฟาสั่งทำ
# 27566         YELLOW           เหลือง        58           โซฟา 2 ที่นั่ง
# 27567          GREEN            เขียว        AU             อาร์มแชร์ผ้า
# 27568          CREAM             ครีม        61               โซฟาสั่งทำ
# 27569          GREEN            เขียว        61               โซฟาสั่งทำ
# 27570         VIOLET          ไวโอแลต        61               โซฟาสั่งทำ
# 27571           GREY              เทา        61               โซฟาสั่งทำ
#
#                  LTEXT_T
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3            Bedroom Set
# 4            Bedroom Set
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28     Dining Table/Wood
# 29                   NaN
# ...                  ...
# 27542                NaN
# 27543                NaN
# 27544                NaN
# 27545                NaN
# 27546                NaN
# 27547                NaN
# 27548                NaN
# 27549                NaN
# 27550                NaN
# 27551                NaN
# 27552                NaN
# 27553                NaN
# 27554                NaN
# 27555                NaN
# 27556  Dining Table/Wood
# 27557                NaN
# 27558                NaN
# 27559                NaN
# 27560                NaN
# 27561                NaN
# 27562                NaN
# 27563                NaN
# 27564                NaN
# 27565                NaN
# 27566                NaN
# 27567                NaN
# 27568                NaN
# 27569                NaN
# 27570                NaN
# 27571                NaN
#
# [27572 rows x 16 columns]

# %% [markdown]
# # Explore

# %%
sns.heatmap(product_merge.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df_product = product_merge[['MATNR','Model','Color','Style','Cat2']]
df_product
# Out:
#           MATNR     Model          Color             Style  \
# 0      19047936   Patisia          WHITE           Vintage
# 1      19045101   Cannery         YELLOW            Modern
# 2      19050282       NaN   MULTI-COLOUR           Vintage
# 3      59000365    Meudon     DARK SHADE      Contemporary
# 4      59001810    Alicia          WHITE            Modern
# 5      19049900   Santana          WHITE            Modern
# 6      19040929     Bella          BROWN    Modern Italian
# 7      19045046      Jovi          BLACK            Modern
# 8      19045211    Grazia         WALNUT      Contemporary
# 9      59000343    Koloze         WALNUT            Modern
# 10     19042680    Kokoro         VIOLET      Contemporary
# 11     19050326    Levonn          WHITE  Luxury Glamorous
# 12     19050327   Latanya           GREY  Luxury Glamorous
# 13     19042726      Ives         VIOLET            Modern
# 14     19045832     Maxio          WHITE    Modern Italian
# 15     19050328   Latanya           GREY  Luxury Glamorous
# 16     19050345     Yitta        CROMIUM  Luxury Glamorous
# 17     19047934   Patisia          WHITE           Vintage
# 18     19049891    Kabira           GREY    Modern Classic
# 19     19050324    Leewan           GREY  Luxury Glamorous
# 20     19050325    Levonn          WHITE  Luxury Glamorous
# 21     19045031    Mamara          BROWN            Modern
# 22     19045032    Mamara          CREAM            Modern
# 23     19035030      Exio          BLACK    Modern Italian
# 24     19042705    Angela          CREAM       Modern Chic
# 25     19046676      Coco            RED            Modern
# 26     19049870  Terminus          WENGE            Modern
# 27     19049871  Terminus          WENGE            Modern
# 28     59000712   Jocasta          WHITE    Modern Classic
# 29     59000614    Hybrid            NaN      Contemporary
# ...         ...       ...            ...               ...
# 27542  19138746   A-Sonia          BROWN               NaN
# 27543  19139148   Espanso          BROWN               NaN
# 27544  19132025    Trixie   SMOKE TIMBER            Modern
# 27545  19132830   Restrol  DARK SHERWOOD            Modern
# 27546  19134126      0529            NaN            Modern
# 27547  19134146      0529            NaN            Modern
# 27548  19134382      0530            NaN            Modern
# 27549  19140271     Hanly           GREY               NaN
# 27550  19140411    Xantic        NATURAL               NaN
# 27551  19140588     Dante          BROWN               NaN
# 27552  19140589     Dante          BROWN               NaN
# 27553  19140590     Dante          BLACK               NaN
# 27554  19140591     Dante          BROWN               NaN
# 27555  19125474   Finetti            NaN            Modern
# 27556  19135987     Lacee   NATURAL WOOD      Contemporary
# 27557  19131725       Tag          BROWN      Contemporary
# 27558  19135988     Lacee          GREEN      Contemporary
# 27559  19136286     Earra          BLACK               NaN
# 27560  19136287    Effect          BLACK               NaN
# 27561  19136288     Econo          BLACK               NaN
# 27562  19136289     Enema          BLACK               NaN
# 27563  19134398      0530            NaN            Modern
# 27564  19134406      0530            NaN            Modern
# 27565  19134454      0530            NaN            Modern
# 27566  19140598   Rebecca         YELLOW               NaN
# 27567  19140896    Mirada          GREEN               NaN
# 27568  19141036   Rebecca          CREAM               NaN
# 27569  19141037   Rebecca          GREEN               NaN
# 27570  19141038   Rebecca         VIOLET               NaN
# 27571  19141039   Rebecca           GREY               NaN
#
#                           Cat2
# 0                 ตู้ข้างเตียง
# 1               โซฟา 3 ที่นั่ง
# 2                      กรอบรูป
# 3                   ชุดห้องนอน
# 4                   ชุดห้องนอน
# 5               โซฟาเข้ามุมขวา
# 6               โซฟา 3 ที่นั่ง
# 7               โซฟา 4 ที่นั่ง
# 8                        เตียง
# 9                          NaN
# 10              โซฟา 3 ที่นั่ง
# 11              โซฟา 2 ที่นั่ง
# 12              โซฟา 4 ที่นั่ง
# 13                     โซฟาเบด
# 14                       เตียง
# 15              โซฟา 2 ที่นั่ง
# 16                     ตู้โชว์
# 17                     ตู้โชว์
# 18              โซฟา 2 ที่นั่ง
# 19              โซฟา 2 ที่นั่ง
# 20              โซฟา 4 ที่นั่ง
# 21             โซฟาเข้ามุมซ้าย
# 22             โซฟาเข้ามุมซ้าย
# 23        ตู้เสื้อผ้าบานเฟี้ยม
# 24              โซฟา 3 ที่นั่ง
# 25              โซฟา 2 ที่นั่ง
# 26                      ตู้สูง
# 27                   ไซด์บอร์ด
# 28            โต๊ะอาหารไม้ล้วน
# 29                         NaN
# ...                        ...
# 27542           โซฟา 3 ที่นั่ง
# 27543           โซฟา 3 ที่นั่ง
# 27544           เคาน์เตอร์บาร์
# 27545  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27546               โซฟาสั่งทำ
# 27547               โซฟาสั่งทำ
# 27548               โซฟาสั่งทำ
# 27549           โซฟา 3 ที่นั่ง
# 27550  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27551                  ตู้โชว์
# 27552                ไซด์บอร์ด
# 27553             ตู้ข้างเตียง
# 27554                ไซด์บอร์ด
# 27555                    เตียง
# 27556         โต๊ะอาหารไม้ล้วน
# 27557          โซฟาเข้ามุมซ้าย
# 27558      เก้าอี้เหล็กเบาะผ้า
# 27559                   ตู้สูง
# 27560                 ชั้นโล่ง
# 27561                 ชั้นโล่ง
# 27562                 ชั้นโล่ง
# 27563               โซฟาสั่งทำ
# 27564               โซฟาสั่งทำ
# 27565               โซฟาสั่งทำ
# 27566           โซฟา 2 ที่นั่ง
# 27567             อาร์มแชร์ผ้า
# 27568               โซฟาสั่งทำ
# 27569               โซฟาสั่งทำ
# 27570               โซฟาสั่งทำ
# 27571               โซฟาสั่งทำ
#
# [27572 rows x 5 columns]

# %%
sns.heatmap(df_product.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
len(df_product['MATNR'])
# Out:
# 27572

# %%
df_product_f = df_product.fillna('zNone')
df_product_f
#df_product.dropna(inplace=True)
# Out:
#           MATNR     Model          Color             Style  \
# 0      19047936   Patisia          WHITE           Vintage
# 1      19045101   Cannery         YELLOW            Modern
# 2      19050282     zNone   MULTI-COLOUR           Vintage
# 3      59000365    Meudon     DARK SHADE      Contemporary
# 4      59001810    Alicia          WHITE            Modern
# 5      19049900   Santana          WHITE            Modern
# 6      19040929     Bella          BROWN    Modern Italian
# 7      19045046      Jovi          BLACK            Modern
# 8      19045211    Grazia         WALNUT      Contemporary
# 9      59000343    Koloze         WALNUT            Modern
# 10     19042680    Kokoro         VIOLET      Contemporary
# 11     19050326    Levonn          WHITE  Luxury Glamorous
# 12     19050327   Latanya           GREY  Luxury Glamorous
# 13     19042726      Ives         VIOLET            Modern
# 14     19045832     Maxio          WHITE    Modern Italian
# 15     19050328   Latanya           GREY  Luxury Glamorous
# 16     19050345     Yitta        CROMIUM  Luxury Glamorous
# 17     19047934   Patisia          WHITE           Vintage
# 18     19049891    Kabira           GREY    Modern Classic
# 19     19050324    Leewan           GREY  Luxury Glamorous
# 20     19050325    Levonn          WHITE  Luxury Glamorous
# 21     19045031    Mamara          BROWN            Modern
# 22     19045032    Mamara          CREAM            Modern
# 23     19035030      Exio          BLACK    Modern Italian
# 24     19042705    Angela          CREAM       Modern Chic
# 25     19046676      Coco            RED            Modern
# 26     19049870  Terminus          WENGE            Modern
# 27     19049871  Terminus          WENGE            Modern
# 28     59000712   Jocasta          WHITE    Modern Classic
# 29     59000614    Hybrid          zNone      Contemporary
# ...         ...       ...            ...               ...
# 27542  19138746   A-Sonia          BROWN             zNone
# 27543  19139148   Espanso          BROWN             zNone
# 27544  19132025    Trixie   SMOKE TIMBER            Modern
# 27545  19132830   Restrol  DARK SHERWOOD            Modern
# 27546  19134126      0529          zNone            Modern
# 27547  19134146      0529          zNone            Modern
# 27548  19134382      0530          zNone            Modern
# 27549  19140271     Hanly           GREY             zNone
# 27550  19140411    Xantic        NATURAL             zNone
# 27551  19140588     Dante          BROWN             zNone
# 27552  19140589     Dante          BROWN             zNone
# 27553  19140590     Dante          BLACK             zNone
# 27554  19140591     Dante          BROWN             zNone
# 27555  19125474   Finetti          zNone            Modern
# 27556  19135987     Lacee   NATURAL WOOD      Contemporary
# 27557  19131725       Tag          BROWN      Contemporary
# 27558  19135988     Lacee          GREEN      Contemporary
# 27559  19136286     Earra          BLACK             zNone
# 27560  19136287    Effect          BLACK             zNone
# 27561  19136288     Econo          BLACK             zNone
# 27562  19136289     Enema          BLACK             zNone
# 27563  19134398      0530          zNone            Modern
# 27564  19134406      0530          zNone            Modern
# 27565  19134454      0530          zNone            Modern
# 27566  19140598   Rebecca         YELLOW             zNone
# 27567  19140896    Mirada          GREEN             zNone
# 27568  19141036   Rebecca          CREAM             zNone
# 27569  19141037   Rebecca          GREEN             zNone
# 27570  19141038   Rebecca         VIOLET             zNone
# 27571  19141039   Rebecca           GREY             zNone
#
#                           Cat2
# 0                 ตู้ข้างเตียง
# 1               โซฟา 3 ที่นั่ง
# 2                      กรอบรูป
# 3                   ชุดห้องนอน
# 4                   ชุดห้องนอน
# 5               โซฟาเข้ามุมขวา
# 6               โซฟา 3 ที่นั่ง
# 7               โซฟา 4 ที่นั่ง
# 8                        เตียง
# 9                        zNone
# 10              โซฟา 3 ที่นั่ง
# 11              โซฟา 2 ที่นั่ง
# 12              โซฟา 4 ที่นั่ง
# 13                     โซฟาเบด
# 14                       เตียง
# 15              โซฟา 2 ที่นั่ง
# 16                     ตู้โชว์
# 17                     ตู้โชว์
# 18              โซฟา 2 ที่นั่ง
# 19              โซฟา 2 ที่นั่ง
# 20              โซฟา 4 ที่นั่ง
# 21             โซฟาเข้ามุมซ้าย
# 22             โซฟาเข้ามุมซ้าย
# 23        ตู้เสื้อผ้าบานเฟี้ยม
# 24              โซฟา 3 ที่นั่ง
# 25              โซฟา 2 ที่นั่ง
# 26                      ตู้สูง
# 27                   ไซด์บอร์ด
# 28            โต๊ะอาหารไม้ล้วน
# 29                       zNone
# ...                        ...
# 27542           โซฟา 3 ที่นั่ง
# 27543           โซฟา 3 ที่นั่ง
# 27544           เคาน์เตอร์บาร์
# 27545  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27546               โซฟาสั่งทำ
# 27547               โซฟาสั่งทำ
# 27548               โซฟาสั่งทำ
# 27549           โซฟา 3 ที่นั่ง
# 27550  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27551                  ตู้โชว์
# 27552                ไซด์บอร์ด
# 27553             ตู้ข้างเตียง
# 27554                ไซด์บอร์ด
# 27555                    เตียง
# 27556         โต๊ะอาหารไม้ล้วน
# 27557          โซฟาเข้ามุมซ้าย
# 27558      เก้าอี้เหล็กเบาะผ้า
# 27559                   ตู้สูง
# 27560                 ชั้นโล่ง
# 27561                 ชั้นโล่ง
# 27562                 ชั้นโล่ง
# 27563               โซฟาสั่งทำ
# 27564               โซฟาสั่งทำ
# 27565               โซฟาสั่งทำ
# 27566           โซฟา 2 ที่นั่ง
# 27567             อาร์มแชร์ผ้า
# 27568               โซฟาสั่งทำ
# 27569               โซฟาสั่งทำ
# 27570               โซฟาสั่งทำ
# 27571               โซฟาสั่งทำ
#
# [27572 rows x 5 columns]

# %%
len(df_product_f['MATNR'])
# Out:
# 27572

# %%
df_product = df_product_f
sns.heatmap(df_product.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df_product.reset_index(drop=True)
# Out:
#           MATNR     Model          Color             Style  \
# 0      19047936   Patisia          WHITE           Vintage
# 1      19045101   Cannery         YELLOW            Modern
# 2      19050282     zNone   MULTI-COLOUR           Vintage
# 3      59000365    Meudon     DARK SHADE      Contemporary
# 4      59001810    Alicia          WHITE            Modern
# 5      19049900   Santana          WHITE            Modern
# 6      19040929     Bella          BROWN    Modern Italian
# 7      19045046      Jovi          BLACK            Modern
# 8      19045211    Grazia         WALNUT      Contemporary
# 9      59000343    Koloze         WALNUT            Modern
# 10     19042680    Kokoro         VIOLET      Contemporary
# 11     19050326    Levonn          WHITE  Luxury Glamorous
# 12     19050327   Latanya           GREY  Luxury Glamorous
# 13     19042726      Ives         VIOLET            Modern
# 14     19045832     Maxio          WHITE    Modern Italian
# 15     19050328   Latanya           GREY  Luxury Glamorous
# 16     19050345     Yitta        CROMIUM  Luxury Glamorous
# 17     19047934   Patisia          WHITE           Vintage
# 18     19049891    Kabira           GREY    Modern Classic
# 19     19050324    Leewan           GREY  Luxury Glamorous
# 20     19050325    Levonn          WHITE  Luxury Glamorous
# 21     19045031    Mamara          BROWN            Modern
# 22     19045032    Mamara          CREAM            Modern
# 23     19035030      Exio          BLACK    Modern Italian
# 24     19042705    Angela          CREAM       Modern Chic
# 25     19046676      Coco            RED            Modern
# 26     19049870  Terminus          WENGE            Modern
# 27     19049871  Terminus          WENGE            Modern
# 28     59000712   Jocasta          WHITE    Modern Classic
# 29     59000614    Hybrid          zNone      Contemporary
# ...         ...       ...            ...               ...
# 27542  19138746   A-Sonia          BROWN             zNone
# 27543  19139148   Espanso          BROWN             zNone
# 27544  19132025    Trixie   SMOKE TIMBER            Modern
# 27545  19132830   Restrol  DARK SHERWOOD            Modern
# 27546  19134126      0529          zNone            Modern
# 27547  19134146      0529          zNone            Modern
# 27548  19134382      0530          zNone            Modern
# 27549  19140271     Hanly           GREY             zNone
# 27550  19140411    Xantic        NATURAL             zNone
# 27551  19140588     Dante          BROWN             zNone
# 27552  19140589     Dante          BROWN             zNone
# 27553  19140590     Dante          BLACK             zNone
# 27554  19140591     Dante          BROWN             zNone
# 27555  19125474   Finetti          zNone            Modern
# 27556  19135987     Lacee   NATURAL WOOD      Contemporary
# 27557  19131725       Tag          BROWN      Contemporary
# 27558  19135988     Lacee          GREEN      Contemporary
# 27559  19136286     Earra          BLACK             zNone
# 27560  19136287    Effect          BLACK             zNone
# 27561  19136288     Econo          BLACK             zNone
# 27562  19136289     Enema          BLACK             zNone
# 27563  19134398      0530          zNone            Modern
# 27564  19134406      0530          zNone            Modern
# 27565  19134454      0530          zNone            Modern
# 27566  19140598   Rebecca         YELLOW             zNone
# 27567  19140896    Mirada          GREEN             zNone
# 27568  19141036   Rebecca          CREAM             zNone
# 27569  19141037   Rebecca          GREEN             zNone
# 27570  19141038   Rebecca         VIOLET             zNone
# 27571  19141039   Rebecca           GREY             zNone
#
#                           Cat2
# 0                 ตู้ข้างเตียง
# 1               โซฟา 3 ที่นั่ง
# 2                      กรอบรูป
# 3                   ชุดห้องนอน
# 4                   ชุดห้องนอน
# 5               โซฟาเข้ามุมขวา
# 6               โซฟา 3 ที่นั่ง
# 7               โซฟา 4 ที่นั่ง
# 8                        เตียง
# 9                        zNone
# 10              โซฟา 3 ที่นั่ง
# 11              โซฟา 2 ที่นั่ง
# 12              โซฟา 4 ที่นั่ง
# 13                     โซฟาเบด
# 14                       เตียง
# 15              โซฟา 2 ที่นั่ง
# 16                     ตู้โชว์
# 17                     ตู้โชว์
# 18              โซฟา 2 ที่นั่ง
# 19              โซฟา 2 ที่นั่ง
# 20              โซฟา 4 ที่นั่ง
# 21             โซฟาเข้ามุมซ้าย
# 22             โซฟาเข้ามุมซ้าย
# 23        ตู้เสื้อผ้าบานเฟี้ยม
# 24              โซฟา 3 ที่นั่ง
# 25              โซฟา 2 ที่นั่ง
# 26                      ตู้สูง
# 27                   ไซด์บอร์ด
# 28            โต๊ะอาหารไม้ล้วน
# 29                       zNone
# ...                        ...
# 27542           โซฟา 3 ที่นั่ง
# 27543           โซฟา 3 ที่นั่ง
# 27544           เคาน์เตอร์บาร์
# 27545  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27546               โซฟาสั่งทำ
# 27547               โซฟาสั่งทำ
# 27548               โซฟาสั่งทำ
# 27549           โซฟา 3 ที่นั่ง
# 27550  โต๊ะอาหารขาเหล็กท๊อปไม้
# 27551                  ตู้โชว์
# 27552                ไซด์บอร์ด
# 27553             ตู้ข้างเตียง
# 27554                ไซด์บอร์ด
# 27555                    เตียง
# 27556         โต๊ะอาหารไม้ล้วน
# 27557          โซฟาเข้ามุมซ้าย
# 27558      เก้าอี้เหล็กเบาะผ้า
# 27559                   ตู้สูง
# 27560                 ชั้นโล่ง
# 27561                 ชั้นโล่ง
# 27562                 ชั้นโล่ง
# 27563               โซฟาสั่งทำ
# 27564               โซฟาสั่งทำ
# 27565               โซฟาสั่งทำ
# 27566           โซฟา 2 ที่นั่ง
# 27567             อาร์มแชร์ผ้า
# 27568               โซฟาสั่งทำ
# 27569               โซฟาสั่งทำ
# 27570               โซฟาสั่งทำ
# 27571               โซฟาสั่งทำ
#
# [27572 rows x 5 columns]

# %% [markdown]
# # Prepare Data

# %%
df_model = df_product.drop_duplicates(subset=['Model'])
df_model.sort_values("Model", inplace=True)
df_model_idx = df_model.reset_index(drop=True)
df_model_idx.insert(0, 'Model_id', range(1, 1 + len(df_model)))
df_model_idx.drop(df_model_idx.columns[[1,3,4,5]], axis=1, inplace = True)
mult_model = (len(df_model_idx))*2.1
len_model = int(round(mult_model))
constant = len_model - len(df_model_idx)
cons = int(round(constant))
df_model_idx.loc[df_model_idx.Model == 'zNone', 'Model_id'] = len_model
df_model_idx
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Model_id    Model
# 0            1     0120
# 1            2     0121
# 2            3     0130
# 3            4     0133
# 4            5    0138V
# 5            6     0177
# 6            7     0186
# 7            8     0213
# 8            9    0218A
# 9           10     0229
# 10          11     0230
# 11          12     0274
# 12          13     0283
# 13          14     0422
# 14          15     0425
# 15          16     0435
# 16          17    0456A
# 17          18     0529
# 18          19     0530
# 19          20      118
# 20          21   118092
# 21          22   125030
# 22          23   125101
# 23          24   138032
# 24          25   139003
# 25          26   159040
# 26          27   159043
# 27          28   159044
# 28          29   159062
# 29          30   165091
# ...        ...      ...
# 3887      3888    Zirka
# 3888      3889    Zitko
# 3889      3890    Zitra
# 3890      3891    Zivic
# 3891      3892    Zixar
# 3892      3893     Ziza
# 3893      3894    Zlass
# 3894      3895    Zobah
# 3895      3896     Zoji
# 3896      3897     Zoki
# 3897      3898     Zola
# 3898      3899     Zoma
# 3899      3900    Zonta
# 3900      3901    Zooma
# 3901      3902   Zorana
# 3902      3903    Zorio
# 3903      3904    Zorun
# 3904      3905    Zosia
# 3905      3906     Zota
# 3906      3907    Zound
# 3907      3908     Zoup
# 3908      3909      Zow
# 3909      3910     Zula
# 3910      3911  Zurface
# 3911      3912    Zylus
# 3912      3913  addison
# 3913      3914      ago
# 3914      3915     kacy
# 3915      3916     lama
# 3916      8226    zNone
#
# [3917 rows x 2 columns]

# %%
df_color_old = df_product.drop_duplicates(subset=['Color'])
df_color_old.sort_values("Color", inplace=True)
df_color_old_idx = df_color_old.reset_index(drop=True)
df_color_old_idx.insert(0, 'Color_id_old', range(1, 1 + len(df_color_old)))
df_color_old_idx.drop(df_color_old_idx.columns[[1,2,4,5]], axis=1, inplace = True)
len_color_old = len(df_color_old_idx)
df_color_old_idx.loc[df_color_old_idx.Color == 'zNone', 'Color_id_old'] = len_color_old + constant
df_color_old_idx
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Color_id_old               Color
# 0              1            ALUMINUM
# 1              2         AMBER BROWN
# 2              3  ANTIQUE WHITE WASH
# 3              4        AUTUMN BROWN
# 4              5     Almond Yosemite
# 5              6            B-AFRICA
# 6              7               BEECH
# 7              8               BEIGE
# 8              9               BLACK
# 9             10     BLACK MILLENIUM
# 10            11       BLACK MUSTANG
# 11            12                BLUE
# 12            13              BRONZE
# 13            14         BRONZE WAVE
# 14            15               BROWN
# 15            16               Brass
# 16            17             CARRARA
# 17            18            CHARCOLE
# 18            19              CHERRY
# 19            20               CLEAR
# 20            21         COCOA BROWN
# 21            22            COLORFUL
# 22            23          COOL WHITE
# 23            24              COPPER
# 24            25               CREAM
# 25            26         CROCO BLACK
# 26            27         CROCO WHITE
# 27            28             CROMIUM
# 28            29             Camelia
# 29            30          Canyon Oak
# ..           ...                 ...
# 66            67              ORANGE
# 67            68         PEARL WHITE
# 68            69                PINK
# 69            70            PRINTING
# 70            71              PURPLE
# 71            72                 RED
# 72            73             REFLECT
# 73            74        ROYAL ACACIA
# 74            75         SATIN NIKLE
# 75            76              SHADOW
# 76            77     SIENNA YOSEMITE
# 77            78              SILVER
# 78            79             SILVERA
# 79            80        SMOKE TIMBER
# 80            81           SOFT GREY
# 81            82           SOLID OAK
# 82            83           STAINLESS
# 83            84         SYRUP BROWN
# 84            85             TORTORA
# 85            86          TRAVERTINE
# 86            87           TURQOUISE
# 87            88               VIOLA
# 88            89              VIOLET
# 89            90              WALNUT
# 90            91               WENGE
# 91            92               WHITE
# 92            93           WHITE OAK
# 93            94         WHITE SHADE
# 94            95              YELLOW
# 95          4405               zNone
#
# [96 rows x 2 columns]

# %%
df_style = df_product.drop_duplicates(subset=['Style'])
df_style.sort_values("Style", inplace=True)
df_style_idx = df_style.reset_index(drop=True)
df_style_idx.insert(0, 'Style_id', range(1, 1 + len(df_style)))
df_style_idx.drop(df_style_idx.columns[[1,2,3,5]], axis=1, inplace = True)
len_style_idx = len(df_style_idx)
df_style_idx.loc[df_style_idx.Style == 'zNone', 'Style_id'] = len_style_idx + constant
df_style_idx
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Style_id                Style
# 0          1              Antique
# 1          2              Artdeco
# 2          3              Classic
# 3          4       Colour Passion
# 4          5         Contemporary
# 5          6              Ecolism
# 6          7           Industrial
# 7          8                 Loft
# 8          9               Luxury
# 9         10     Luxury Glamorous
# 10        11              Minimal
# 11        12               Modern
# 12        13          Modern Chic
# 13        14       Modern Classic
# 14        15  Modern Contemporary
# 15        16       Modern Italian
# 16        17        Modern Luxury
# 17        18  Modern Scandinavian
# 18        19          Neo Baroque
# 19        20      Oriental Aspire
# 20        21          Renaissance
# 21        22         Scandinavian
# 22        23         Transitional
# 23        24              Vintage
# 24      4334                zNone

# %%
df_cat2 = df_product.drop_duplicates(subset=['Cat2'])
df_cat2.sort_values("Cat2", inplace=True)
df_cat2_idx = df_cat2.reset_index(drop=True)
df_cat2_idx.insert(0, 'Cat2_id', range(1, 1 + len(df_cat2)))
df_cat2_idx.drop(df_cat2_idx.columns[[1,2,3,4]], axis=1, inplace = True)
len_cat2_idx = len(df_cat2_idx)
df_cat2_idx.loc[df_cat2_idx.Cat2 == 'zNone', 'Cat2_id'] = len_cat2_idx + constant
df_cat2_idx
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      Cat2_id                          Cat2
# 0          1                    **Delete**
# 1          2                Door's Fitting
# 2          3                       TV Flip
# 3       4566                         zNone
# 4          5                       กรอบรูป
# 5          6              กระจกแบบตั้งพื้น
# 6          7              กระจกแบบตั้งโต๊ะ
# 7          8               กระจกแบบติดผนัง
# 8          9                  กระจกแบบแขวน
# 9         10                  กระถางต้นไม้
# 10        11                       กระเป๋า
# 11        12     กริ่งสนทนาเห็นภาพและเสียง
# 12        13              กลอนประตูดิจิตอล
# 13        14                   กล่องทิชชู่
# 14        15                    กล่องบานยก
# 15        16                  กล่องลิ้นชัก
# 16        17              กล่องอเนกประสงค์
# 17        18                     กล่องแขวน
# 18        19        กล่องและภาชนะเก็บอาหาร
# 19        20                     กล่องโล่ง
# 20        21                 กล่องใส่กุญแจ
# 21        22               กล่องใส่นามบัตร
# 22        23               กล่องใส่นิตยสาร
# 23        24         กล่องใส่เครื่องประดับ
# 24        25                    กล้องตาแมว
# 25        26                ขวดเครื่องปรุง
# 26        27             ของขวัญสำหรับเด็ก
# 27        28               ของตกแต่งอื่น ๆ
# 28        29             ของตกแต่งเหล็กดัด
# 29        30             ของใช้บนโต๊ะอาหาร
# ..       ...                           ...
# 227      228          โต๊ะข้างเหล็กท๊อปไม้
# 228      229             โต๊ะข้างเหล็กล้วน
# 229      230           โต๊ะข้างไฟเบอร์กลาส
# 230      231          โต๊ะข้างไม้ท๊อปกระจก
# 231      232            โต๊ะข้างไม้ท๊อปหิน
# 232      233               โต๊ะข้างไม้ล้วน
# 233      234               โต๊ะคอมพิวเตอร์
# 234      235                     โต๊ะทำงาน
# 235      236                 โต๊ะทำงาน IHD
# 236      237        โต๊ะบาร์ขาเหล็กท๊อปไม้
# 237      238                      โต๊ะสนาม
# 238      239                  โต๊ะหมู่บูชา
# 239      240            โต๊ะอาหารกระจกล้วน
# 240      241       โต๊ะอาหารขาหินท๊อปกระจก
# 241      242     โต๊ะอาหารขาเหล็กท๊อปกระจก
# 242      243       โต๊ะอาหารขาเหล็กท๊อปหิน
# 243      244       โต๊ะอาหารขาเหล็กท๊อปไม้
# 244      245       โต๊ะอาหารขาไม้ท๊อปกระจก
# 245      246         โต๊ะอาหารขาไม้ท๊อปหิน
# 246      247               โต๊ะอาหารสั่งทำ
# 247      248              โต๊ะอาหารหินล้วน
# 248      249            โต๊ะอาหารเหล็กล้วน
# 249      250  โต๊ะอาหารไฟเบอร์กลาส/พลาสติก
# 250      251              โต๊ะอาหารไม้ล้วน
# 251      252              โต๊ะเขียนหนังสือ
# 252      253        โต๊ะเครื่องแป้งแบบนั่ง
# 253      254         โต๊ะเครื่องแป้งแบบยืน
# 254      255               โถเซรามิค/โถหิน
# 255      256                     โป๊ะโคมไฟ
# 256      257                     ไซด์บอร์ด
#
# [257 rows x 2 columns]

# %%
df_product = pd.merge(df_product, df_model_idx,  how='left', left_on=['Model'], right_on = ['Model'])
df_product = pd.merge(df_product, df_color_old_idx,  how='left', left_on=['Color'], right_on = ['Color'])
df_product
# Out:
#           MATNR     Model          Color             Style  \
# 0      19047936   Patisia          WHITE           Vintage
# 1      19045101   Cannery         YELLOW            Modern
# 2      19050282     zNone   MULTI-COLOUR           Vintage
# 3      59000365    Meudon     DARK SHADE      Contemporary
# 4      59001810    Alicia          WHITE            Modern
# 5      19049900   Santana          WHITE            Modern
# 6      19040929     Bella          BROWN    Modern Italian
# 7      19045046      Jovi          BLACK            Modern
# 8      19045211    Grazia         WALNUT      Contemporary
# 9      59000343    Koloze         WALNUT            Modern
# 10     19042680    Kokoro         VIOLET      Contemporary
# 11     19050326    Levonn          WHITE  Luxury Glamorous
# 12     19050327   Latanya           GREY  Luxury Glamorous
# 13     19042726      Ives         VIOLET            Modern
# 14     19045832     Maxio          WHITE    Modern Italian
# 15     19050328   Latanya           GREY  Luxury Glamorous
# 16     19050345     Yitta        CROMIUM  Luxury Glamorous
# 17     19047934   Patisia          WHITE           Vintage
# 18     19049891    Kabira           GREY    Modern Classic
# 19     19050324    Leewan           GREY  Luxury Glamorous
# 20     19050325    Levonn          WHITE  Luxury Glamorous
# 21     19045031    Mamara          BROWN            Modern
# 22     19045032    Mamara          CREAM            Modern
# 23     19035030      Exio          BLACK    Modern Italian
# 24     19042705    Angela          CREAM       Modern Chic
# 25     19046676      Coco            RED            Modern
# 26     19049870  Terminus          WENGE            Modern
# 27     19049871  Terminus          WENGE            Modern
# 28     59000712   Jocasta          WHITE    Modern Classic
# 29     59000614    Hybrid          zNone      Contemporary
# ...         ...       ...            ...               ...
# 27542  19138746   A-Sonia          BROWN             zNone
# 27543  19139148   Espanso          BROWN             zNone
# 27544  19132025    Trixie   SMOKE TIMBER            Modern
# 27545  19132830   Restrol  DARK SHERWOOD            Modern
# 27546  19134126      0529          zNone            Modern
# 27547  19134146      0529          zNone            Modern
# 27548  19134382      0530          zNone            Modern
# 27549  19140271     Hanly           GREY             zNone
# 27550  19140411    Xantic        NATURAL             zNone
# 27551  19140588     Dante          BROWN             zNone
# 27552  19140589     Dante          BROWN             zNone
# 27553  19140590     Dante          BLACK             zNone
# 27554  19140591     Dante          BROWN             zNone
# 27555  19125474   Finetti          zNone            Modern
# 27556  19135987     Lacee   NATURAL WOOD      Contemporary
# 27557  19131725       Tag          BROWN      Contemporary
# 27558  19135988     Lacee          GREEN      Contemporary
# 27559  19136286     Earra          BLACK             zNone
# 27560  19136287    Effect          BLACK             zNone
# 27561  19136288     Econo          BLACK             zNone
# 27562  19136289     Enema          BLACK             zNone
# 27563  19134398      0530          zNone            Modern
# 27564  19134406      0530          zNone            Modern
# 27565  19134454      0530          zNone            Modern
# 27566  19140598   Rebecca         YELLOW             zNone
# 27567  19140896    Mirada          GREEN             zNone
# 27568  19141036   Rebecca          CREAM             zNone
# 27569  19141037   Rebecca          GREEN             zNone
# 27570  19141038   Rebecca         VIOLET             zNone
# 27571  19141039   Rebecca           GREY             zNone
#
#                           Cat2  Model_id  Color_id_old
# 0                 ตู้ข้างเตียง      2886            92
# 1               โซฟา 3 ที่นั่ง       719            95
# 2                      กรอบรูป      8226            61
# 3                   ชุดห้องนอน      2542            32
# 4                   ชุดห้องนอน       295            92
# 5               โซฟาเข้ามุมขวา      3107            92
# 6               โซฟา 3 ที่นั่ง       564            15
# 7               โซฟา 4 ที่นั่ง      2040             9
# 8                        เตียง      1519            90
# 9                        zNone      2139            90
# 10              โซฟา 3 ที่นั่ง      2137            89
# 11              โซฟา 2 ที่นั่ง      2299            92
# 12              โซฟา 4 ที่นั่ง      2238            42
# 13                     โซฟาเบด      1965            89
# 14                       เตียง      2490            92
# 15              โซฟา 2 ที่นั่ง      2238            42
# 16                     ตู้โชว์      3786            28
# 17                     ตู้โชว์      2886            92
# 18              โซฟา 2 ที่นั่ง      2056            42
# 19              โซฟา 2 ที่นั่ง      2264            42
# 20              โซฟา 4 ที่นั่ง      2299            92
# 21             โซฟาเข้ามุมซ้าย      2444            15
# 22             โซฟาเข้ามุมซ้าย      2444            25
# 23        ตู้เสื้อผ้าบานเฟี้ยม      1245             9
# 24              โซฟา 3 ที่นั่ง       366            25
# 25              โซฟา 2 ที่นั่ง       877            72
# 26                      ตู้สูง      3341            91
# 27                   ไซด์บอร์ด      3341            91
# 28            โต๊ะอาหารไม้ล้วน      2021            92
# 29                       zNone      1695          4405
# ...                        ...       ...           ...
# 27542           โซฟา 3 ที่นั่ง       174            15
# 27543           โซฟา 3 ที่นั่ง      1225            15
# 27544           เคาน์เตอร์บาร์      3407            80
# 27545  โต๊ะอาหารขาเหล็กท๊อปไม้      3021            33
# 27546               โซฟาสั่งทำ        18          4405
# 27547               โซฟาสั่งทำ        18          4405
# 27548               โซฟาสั่งทำ        19          4405
# 27549           โซฟา 3 ที่นั่ง      1580            42
# 27550  โต๊ะอาหารขาเหล็กท๊อปไม้      3697            63
# 27551                  ตู้โชว์       986            15
# 27552                ไซด์บอร์ด       986            15
# 27553             ตู้ข้างเตียง       986             9
# 27554                ไซด์บอร์ด       986            15
# 27555                    เตียง      1324          4405
# 27556         โต๊ะอาหารไม้ล้วน      2183            64
# 27557          โซฟาเข้ามุมซ้าย      3299            15
# 27558      เก้าอี้เหล็กเบาะผ้า      2183            41
# 27559                   ตู้สูง      1122             9
# 27560                 ชั้นโล่ง      1146             9
# 27561                 ชั้นโล่ง      1134             9
# 27562                 ชั้นโล่ง      1193             9
# 27563               โซฟาสั่งทำ        19          4405
# 27564               โซฟาสั่งทำ        19          4405
# 27565               โซฟาสั่งทำ        19          4405
# 27566           โซฟา 2 ที่นั่ง      3011            95
# 27567             อาร์มแชร์ผ้า      2571            41
# 27568               โซฟาสั่งทำ      3011            25
# 27569               โซฟาสั่งทำ      3011            41
# 27570               โซฟาสั่งทำ      3011            89
# 27571               โซฟาสั่งทำ      3011            42
#
# [27572 rows x 7 columns]

# %%
df_product.Color = df_product.Color.replace(('WHITE', 'LIGHT SHADE' ,'WHITE SHADE' ,'LIGHT WHITE', 'COOL WHITE' , 'CLEAR' , 'WHITE OAK'  ,'CROCO WHITE' , 'ANTIQUE WHITE WASH', 'PEARL WHITE','Almond Yosemite','Camelia', 'REFLECT','MIRROR', 'CARRARA'), 'White')
df_product.Color = df_product.Color.replace(('YELLOW','CREAM','GLODEN SUN','IVORY'), 'Yellow')
df_product.Color = df_product.Color.replace(('SHADOW','BLACK','DARK SHADE','BLACK MUSTANG','CROCO BLACK','DARK SHERWOOD','SILVERA','DARK EBONY','CHARCOLE','BLACK MILLENIUM','B-AFRICA'), 'Black')
df_product.Color = df_product.Color.replace(('WENGE','ESPRESSO','Mahogany','WALNUT','AUTUMN BROWN','ROYAL ACACIA','SYRUP BROWN','Hazel Timber','COCOA BROWN','SIENNA YOSEMITE','EBONY'), 'Brown Dark')
df_product.Color = df_product.Color.replace(('BEECH','SOLID OAK','OAK','BEIGE','Canyon Oak','IVORY TWIST','TORTORA','Brass','SMOKE TIMBER','LIGHT OAK','FOREST MAPLE','MAPLE'), 'Brown Light')
df_product.Color = df_product.Color.replace(('BROWN','I-WALNUT','ITALIAN BROWN','CHERRY','HPL BRONZE WAVE','NATURAL','AMBER BROWN','BRONZE WAVE','NATURAL WOOD'), 'Brown')
df_product.Color = df_product.Color.replace(('PURPLE','VIOLET','MILD VIOLET','VIOLA'), 'Purple')
df_product.Color = df_product.Color.replace(('GREY','CROMIUM','SILVER','STAINLESS','GREY TWIST','ALUMINIUM','GREY WOOD RIFT','SATIN NIKLE','SOFT GREY','TRAVERTINE','GREY MIRROR','NICKEL GLOSS','ALUMINUM'), 'Grey')
df_product.Color = df_product.Color.replace(('BLUE','Denim'), 'Blue')
df_product.Color = df_product.Color.replace(('GREEN','LIGHT GREEN','TURQOUISE'), 'Green')
df_product.Color = df_product.Color.replace(('ORANGE'), 'Orange')
df_product.Color = df_product.Color.replace(('PINK','MID GLOSS'), 'Pink')
df_product.Color = df_product.Color.replace(('RED'), 'Red')
df_product.Color = df_product.Color.replace(('COLORFUL','MULTI-COLOUR'), 'Multi-Colour')
df_product.Color = df_product.Color.replace(('COPPER','HPL COPPER'), 'Copper')
df_product.Color = df_product.Color.replace(('GOLD','BRONZE','GOLD MIRROR'), 'Gold')
df_product.Color = df_product.Color.replace(('PRINTING'), 'Printing')

# %%
df_color = df_product.drop_duplicates(subset=['Color'])
df_color.sort_values("Color", inplace=True)
df_color_idx = df_color.reset_index(drop=True)
df_color_idx.insert(0, 'Color_id', range(1, 1 + len(df_color)))
df_color_idx.drop(df_color_idx.columns[[1,2,4,5,6,7]], axis=1, inplace = True)
len_color_idx = len(df_color_idx)
df_color_idx.loc[df_color_idx.Color == 'zNone', 'Color_id'] = len_color_idx + constant
df_color_idx
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Color_id         Color
# 0          1         Black
# 1          2          Blue
# 2          3         Brown
# 3          4    Brown Dark
# 4          5   Brown Light
# 5          6        Copper
# 6          7          Gold
# 7          8         Green
# 8          9          Grey
# 9         10  Multi-Colour
# 10        11        Orange
# 11        12          Pink
# 12        13      Printing
# 13        14        Purple
# 14        15           Red
# 15        16         White
# 16        17        Yellow
# 17      4327         zNone

# %%
df_product = pd.merge(df_product, df_color_idx,  how='left', left_on=['Color'], right_on = ['Color'])
df_product = pd.merge(df_product, df_style_idx,  how='left', left_on=['Style'], right_on = ['Style'])
df_product = pd.merge(df_product, df_cat2_idx,  how='left', left_on=['Cat2'], right_on = ['Cat2'])
del df_product['Color_id_old']

# %%
df_product_id = df_product
df_product_id
# Out:
#           MATNR     Model         Color             Style  \
# 0      19047936   Patisia         White           Vintage
# 1      19045101   Cannery        Yellow            Modern
# 2      19050282     zNone  Multi-Colour           Vintage
# 3      59000365    Meudon         Black      Contemporary
# 4      59001810    Alicia         White            Modern
# 5      19049900   Santana         White            Modern
# 6      19040929     Bella         Brown    Modern Italian
# 7      19045046      Jovi         Black            Modern
# 8      19045211    Grazia    Brown Dark      Contemporary
# 9      59000343    Koloze    Brown Dark            Modern
# 10     19042680    Kokoro        Purple      Contemporary
# 11     19050326    Levonn         White  Luxury Glamorous
# 12     19050327   Latanya          Grey  Luxury Glamorous
# 13     19042726      Ives        Purple            Modern
# 14     19045832     Maxio         White    Modern Italian
# 15     19050328   Latanya          Grey  Luxury Glamorous
# 16     19050345     Yitta          Grey  Luxury Glamorous
# 17     19047934   Patisia         White           Vintage
# 18     19049891    Kabira          Grey    Modern Classic
# 19     19050324    Leewan          Grey  Luxury Glamorous
# 20     19050325    Levonn         White  Luxury Glamorous
# 21     19045031    Mamara         Brown            Modern
# 22     19045032    Mamara        Yellow            Modern
# 23     19035030      Exio         Black    Modern Italian
# 24     19042705    Angela        Yellow       Modern Chic
# 25     19046676      Coco           Red            Modern
# 26     19049870  Terminus    Brown Dark            Modern
# 27     19049871  Terminus    Brown Dark            Modern
# 28     59000712   Jocasta         White    Modern Classic
# 29     59000614    Hybrid         zNone      Contemporary
# ...         ...       ...           ...               ...
# 27542  19138746   A-Sonia         Brown             zNone
# 27543  19139148   Espanso         Brown             zNone
# 27544  19132025    Trixie   Brown Light            Modern
# 27545  19132830   Restrol         Black            Modern
# 27546  19134126      0529         zNone            Modern
# 27547  19134146      0529         zNone            Modern
# 27548  19134382      0530         zNone            Modern
# 27549  19140271     Hanly          Grey             zNone
# 27550  19140411    Xantic         Brown             zNone
# 27551  19140588     Dante         Brown             zNone
# 27552  19140589     Dante         Brown             zNone
# 27553  19140590     Dante         Black             zNone
# 27554  19140591     Dante         Brown             zNone
# 27555  19125474   Finetti         zNone            Modern
# 27556  19135987     Lacee         Brown      Contemporary
# 27557  19131725       Tag         Brown      Contemporary
# 27558  19135988     Lacee         Green      Contemporary
# 27559  19136286     Earra         Black             zNone
# 27560  19136287    Effect         Black             zNone
# 27561  19136288     Econo         Black             zNone
# 27562  19136289     Enema         Black             zNone
# 27563  19134398      0530         zNone            Modern
# 27564  19134406      0530         zNone            Modern
# 27565  19134454      0530         zNone            Modern
# 27566  19140598   Rebecca        Yellow             zNone
# 27567  19140896    Mirada         Green             zNone
# 27568  19141036   Rebecca        Yellow             zNone
# 27569  19141037   Rebecca         Green             zNone
# 27570  19141038   Rebecca        Purple             zNone
# 27571  19141039   Rebecca          Grey             zNone
#
#                           Cat2  Model_id  Color_id  Style_id  Cat2_id
# 0                 ตู้ข้างเตียง      2886        16        24       61
# 1               โซฟา 3 ที่นั่ง       719        17        12      203
# 2                      กรอบรูป      8226        10        24        5
# 3                   ชุดห้องนอน      2542         1         5       51
# 4                   ชุดห้องนอน       295        16        12       51
# 5               โซฟาเข้ามุมขวา      3107        16        12      207
# 6               โซฟา 3 ที่นั่ง       564         3        16      203
# 7               โซฟา 4 ที่นั่ง      2040         1        12      204
# 8                        เตียง      1519         4         5      189
# 9                        zNone      2139         4        12     4566
# 10              โซฟา 3 ที่นั่ง      2137        14         5      203
# 11              โซฟา 2 ที่นั่ง      2299        16        10      202
# 12              โซฟา 4 ที่นั่ง      2238         9        10      204
# 13                     โซฟาเบด      1965        14        12      213
# 14                       เตียง      2490        16        16      189
# 15              โซฟา 2 ที่นั่ง      2238         9        10      202
# 16                     ตู้โชว์      3786         9        10       74
# 17                     ตู้โชว์      2886        16        24       74
# 18              โซฟา 2 ที่นั่ง      2056         9        14      202
# 19              โซฟา 2 ที่นั่ง      2264         9        10      202
# 20              โซฟา 4 ที่นั่ง      2299        16        10      204
# 21             โซฟาเข้ามุมซ้าย      2444         3        12      209
# 22             โซฟาเข้ามุมซ้าย      2444        17        12      209
# 23        ตู้เสื้อผ้าบานเฟี้ยม      1245         1        16       69
# 24              โซฟา 3 ที่นั่ง       366        17        13      203
# 25              โซฟา 2 ที่นั่ง       877        15        12      202
# 26                      ตู้สูง      3341         4        12       64
# 27                   ไซด์บอร์ด      3341         4        12      257
# 28            โต๊ะอาหารไม้ล้วน      2021        16        14      251
# 29                       zNone      1695      4327         5     4566
# ...                        ...       ...       ...       ...      ...
# 27542           โซฟา 3 ที่นั่ง       174         3      4334      203
# 27543           โซฟา 3 ที่นั่ง      1225         3      4334      203
# 27544           เคาน์เตอร์บาร์      3407         5        12      185
# 27545  โต๊ะอาหารขาเหล็กท๊อปไม้      3021         1        12      244
# 27546               โซฟาสั่งทำ        18      4327        12      206
# 27547               โซฟาสั่งทำ        18      4327        12      206
# 27548               โซฟาสั่งทำ        19      4327        12      206
# 27549           โซฟา 3 ที่นั่ง      1580         9      4334      203
# 27550  โต๊ะอาหารขาเหล็กท๊อปไม้      3697         3      4334      244
# 27551                  ตู้โชว์       986         3      4334       74
# 27552                ไซด์บอร์ด       986         3      4334      257
# 27553             ตู้ข้างเตียง       986         1      4334       61
# 27554                ไซด์บอร์ด       986         3      4334      257
# 27555                    เตียง      1324      4327        12      189
# 27556         โต๊ะอาหารไม้ล้วน      2183         3         5      251
# 27557          โซฟาเข้ามุมซ้าย      3299         3         5      209
# 27558      เก้าอี้เหล็กเบาะผ้า      2183         8         5      173
# 27559                   ตู้สูง      1122         1      4334       64
# 27560                 ชั้นโล่ง      1146         1      4334       36
# 27561                 ชั้นโล่ง      1134         1      4334       36
# 27562                 ชั้นโล่ง      1193         1      4334       36
# 27563               โซฟาสั่งทำ        19      4327        12      206
# 27564               โซฟาสั่งทำ        19      4327        12      206
# 27565               โซฟาสั่งทำ        19      4327        12      206
# 27566           โซฟา 2 ที่นั่ง      3011        17      4334      202
# 27567             อาร์มแชร์ผ้า      2571         8      4334      143
# 27568               โซฟาสั่งทำ      3011        17      4334      206
# 27569               โซฟาสั่งทำ      3011         8      4334      206
# 27570               โซฟาสั่งทำ      3011        14      4334      206
# 27571               โซฟาสั่งทำ      3011         9      4334      206
#
# [27572 rows x 9 columns]

# %%
df_product_id['Color'].unique()
# Out:
# array(['White', 'Yellow', 'Multi-Colour', 'Black', 'Brown', 'Brown Dark',
#        'Purple', 'Grey', 'Red', 'zNone', 'Blue', 'Brown Light', 'Green',
#        'Orange', 'Gold', 'Pink', 'Printing', 'Copper'], dtype=object)

# %% [markdown]
# # Nearest Neighbors Model

# %%
from sklearn.neighbors import NearestNeighbors

input_item = 19135988
input_index = df_product_id.index[df_product_id['MATNR'] == input_item].tolist()[0]
call_frame = df_product_id.loc[(df_product_id.MATNR.isin([input_item])), ['Color_id', 'Style_id', 'Cat2_id']]
item = call_frame.values

product = df_product_id.iloc[:,6:9].values
nbrs = NearestNeighbors(n_neighbors=11).fit(product)
nbrs_res = nbrs.kneighbors([item[0]])[1]
nbrs_list = nbrs_res.tolist()[0]
while input_index in nbrs_list: nbrs_list.remove(input_index)
result = nbrs_list
#print(result)
df_product_id.iloc[result]
# Out:
#           MATNR     Model  Color           Style                  Cat2  \
# 4118   19067322      Eski  Green  Colour Passion   เก้าอี้เหล็กเบาะผ้า
# 66     19052062     Kadin   Grey         Ecolism      เก้าอี้เหล็กล้วน
# 1420   19042329     Topaz   Grey    Contemporary  เก้าอี้เหล็กเบาะหนัง
# 2553   19041622      Muso   Grey    Contemporary  เก้าอี้เหล็กเบาะหนัง
# 4668   19060372     Topaz   Grey    Contemporary  เก้าอี้เหล็กเบาะหนัง
# 1278   19037997     Lagos   Grey    Contemporary  เก้าอี้เหล็กเบาะหนัง
# 12929  19022879     Lagos   Grey    Contemporary  เก้าอี้เหล็กเบาะหนัง
# 2361   19060181     Lagos   Grey    Contemporary  เก้าอี้เหล็กเบาะหนัง
# 1522   19046495  Tellnews   Grey         Artdeco   เก้าอี้เหล็กเบาะผ้า
# 18226  19062247     Wenda   Grey         Artdeco   เก้าอี้เหล็กเบาะผ้า
#
#        Model_id  Color_id  Style_id  Cat2_id
# 4118       1222         8         4      173
# 66         2060         9         6      172
# 1420       3384         9         5      175
# 2553       2651         9         5      175
# 4668       3384         9         5      175
# 1278       2195         9         5      175
# 12929      2195         9         5      175
# 2361       2195         9         5      175
# 1522       3336         9         2      173
# 18226      3633         9         2      173

# %% [markdown]
# <b>Check Item</b>

# %%
product_merge.loc[product_merge['Color'] == 'GREY' ]
# Out:
#        Item_Codename                                     MAKTX MVGR2 MVGR4  \
# 12          19050327   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/4S   AB4    60
# 15          19050328   โซฟาLATANYA#LC-091201/ผ้ากำมะหยี่เทา/2S   AB4    58
# 18          19049891      โซฟาKABIRA#KS1003/ผ้าเทาลาย#JBY-4/2S   Z52    58
# 19          19050324          โซฟาLEEWAN#LC-36/SLบรอนซ์เงิน/2S   AC2    58
# 30          19049890      โซฟาKABIRA#KS1003/ผ้าเทาลาย#JBY-4/1S   Z52    57
# 32          19049898  ARMCHAIR KENT#KY1021/ผ้าทอง/ผ้าลายโทนเทา   Z73    AU
# 133         19045174  โซฟาเบดKANIRO-PLUS/โครเมียม/ผ้าเทา#12/3S   570    68
# 138         19050467     โซฟาKINSANA/โครม/ผ้าคราม#HE105-13/DBข   HK2    62
# 187         19056072                CONSOLE CHONTE/ไม้ขัดสีเทา   EZ5    C6
# 188         19050215  โซฟาBRINA#BU-2010/ผ้ายีนส์สีเทา#D2/มุมซ.   X16    64
# 193         19059066             ตู้วางของWALDO/เหล็กสีเทาอ่อน   HB4    E0
# 233         19059794        โซฟาNOVELLA/TRUSEN/เทาGR#4101//มุม   HD1    67
# 276         19052007    EVELYN/ไซบอร์ดTV180/D01/GREY WOOD RIFT   108    B1
# 293         19052009     EVELYN/ตู้ลช.C120/DW01/GREY WOOD RIFT   108    D3
# 329         19062914       ETAN/ตู้สูงCT120/D05/GREY WOOD RIFT   ES8    E4
# 348         19041370                      ABLE/ขาเหล็กLE/เทาดำ   001    K4
# 349         19062918           ETAN/คอนโซลCS180/GREY WOOD RIFT   ES8    90
# 359         19041143            เก้าอี้ YAZID(829CH)/SLเทา#D28   401    29
# 364         19052010    EVELYN/ตู้ข้างNT60/DW01/GREY WOOD RIFT   108    70
# 461         19055551     โต๊ะข้างKERMA-D/เหล็กขัดสีเทา/กระจกใส   EE9    88
# 469         19062913       ETAN/ตู้ผ้าWO220/D05/GREY WOOD RIFT   ES8    D4
# 606         19108478                         โซฟาNELZA#2/SLเทา   NJ9    59
# 610         19049738                   VPกระจก DE1324/สีเทา***   IH7    B5
# 619         25010350                           ของตกแต่ง#66702          J8
# 628         25009390                    VPกรอบรูป#DE6047/สีเทา   IH8    B4
# 683         19129721   ELMO/ตู้รองเท้าSH80/เทาดำ/ออทัมน์บราวน์   VG1    E2
# 764         19055554                  โต๊ะข้างKAP/ไม้ขัดสีโอ๊ค   EE6    83
# 808         25010354                           ของตกแต่ง#66674          J8
# 830         25009638      VPของตกแต่ง13-3/4''#DE1597/ไม้/เหล็ก   II6    J8
# 864         25009639          VPของตกแต่ง18''#DE1598/ไม้/เหล็ก   II6    J8
# ...              ...                                       ...   ...   ...
# 27136       19133329   คอนโซล597B816/ไม้Oak/ขาว/Topเทา/D.Wd***   XH2    C6
# 27163       19133992  โต๊ะอาหารFUKUOKA-80/พ่นดำ/หินอ่อนเทาอ่อน   XA8    A6
# 27178       19138521                      โซฟาKORODA/ผ้าเทา/2S   YP3    58
# 27189       19125397     โซฟาGANGZA#3/หนังแท้/SL/เทา/มุม(ซ้าย)   RO2    64
# 27202       19126933                  โซฟาCOUPLE/ผ้าเทา/มุมขวา   VB7    62
# 27204       19125294                        โซฟาLOCY/ผ้าเทา/3S   US2    59
# 27207       19138525           โซฟาVONAZ/โครม/ผ้าเทาดำ/มุมซ้าย   YP5    64
# 27208       19133524   เก้าอี้572639-RTA/ไม้Poplar/เทา/Auth***   XH6    32
# 27216       19138406         โซฟาFURAMA#2/หนังแท้/SLเทา/มุมขวา   UI3    62
# 27220       19134059                โซฟาLOLA/ผ้าเทาเข้ม/มุมขวา   XN4    62
# 27246       19138743      โซฟาA-MONROE/EBONY/ผ้ากำมะหยี่เทา/3S   YP8    59
# 27252       19133972      โซฟาCOMMU/ไม้ธรรมชาติ/ผ้าเทา/มุมซ้าย   XL5    64
# 27262       19136181        สตูล#179064/อะคริลิค+ผ้า/เทา+ใส***   YL6    H0
# 27272       19141005   โซฟาU-PRINCE/น้ำตาล/ผ้าเทาอ่อน#BL371/3S   NaN    59
# 27296       19141006                  โซฟาเบดUNNA/ผ้าเทา#BL370   NaN    68
# 27302       19133973       โซฟาCOMMU/ไม้ธรรมชาติ/ผ้าเทา/มุมขวา   XL5    62
# 27318       19136390                 โต๊ะข้างSAINA/ NICKEL/เทา   YK5    86
# 27330       19138524            โซฟาVONAZ/โครม/ผ้าเทาดำ/มุมขวา   YP5    62
# 27336       19138744      โซฟาA-MONROE/EBONY/ผ้ากำมะหยี่เทา/2S   YP8    58
# 27383       19134971               โซฟา686501-617/ผ้าเทา/3S***   YD5    59
# 27442       19135993             โซฟาYONO#3/ผ้าเทาเข้ม/มุม(ZR)   NZ1    67
# 27455       25026047  SCH ที่คั่นหนังสือ#C161524X26เรซิ่นเทาCT   NaN    L5
# 27463       19140040                โซฟาLIDEN/ดำ/ผ้าเทา/มุมขวา   YR5    62
# 27476       19128102              โซฟาGUEST/ผ้าลายหนังสีเทา/2S   VE5    58
# 27478       19140414    โซฟาSANANTY/หนังแท้/SLเทาดำ#901/มุมขวา   YU1    62
# 27527       19140272                   โซฟาHEMAL/ผ้าเทา/มุมขวา   YT7    62
# 27533       19126774           RECLINER ZABOMB/ผ้าเทา#C185/1RE   VA1    15
# 27534       19126775           RECLINER ZABOMB/ผ้าเทา#C185/3RE   VA1    17
# 27549       19140271                       โซฟาHANLY/ผ้าเทา/3S   YT6    59
# 27571       19141039               โซฟาREBECCA#2/ผ้าเทาดำHC/2S   ST3    61
#
#       MVGR6 STY_ID             Style Node_model             Model  \
# 12       34      5  Luxury Glamorous        AB4           Latanya
# 15       34      5  Luxury Glamorous        AB4           Latanya
# 18       34      8    Modern Classic        Z52            Kabira
# 19       34      5  Luxury Glamorous        AC2            Leewan
# 30       34      8    Modern Classic        Z52            Kabira
# 32       34     10       Neo Baroque        Z73              Kent
# 133      34      6            Modern        570            Kaniro
# 138      34      6            Modern        HK2           Kinsana
# 187      34     14           Vintage        EZ5            Chonte
# 188      34      4           Ecolism        X16             Brina
# 193      34    NaN               NaN        HB4             Waldo
# 233      34      6            Modern        HD1           Novella
# 276      34      8    Modern Classic        108            Evelyn
# 293      34      8    Modern Classic        108            Evelyn
# 329      34     14           Vintage        ES8              Etan
# 348      34      6            Modern        001              Able
# 349      34      8    Modern Classic        ES8              Etan
# 359      34      6            Modern        401             Yazid
# 364      34      8    Modern Classic        108            Evelyn
# 461      34    NaN               NaN        EE9             Kerma
# 469      34      8    Modern Classic        ES8              Etan
# 606      34      6            Modern        NJ9             Nelza
# 610      34     14           Vintage        IH7           CHATEAU
# 619      34     14           Vintage        NaN               NaN
# 628      34     14           Vintage        IH8  CLASSIC ELEGANCE
# 683      34    NaN               NaN        VG1              Elmo
# 764      34    NaN               NaN        EE6               Kap
# 808      34     14           Vintage        NaN               NaN
# 830      34     14           Vintage        II6           SEASIDE
# 864      34     14           Vintage        II6           SEASIDE
# ...     ...    ...               ...        ...               ...
# 27136    34    NaN               NaN        XH2           Dogwood
# 27163    34      6            Modern        XA8           Fukuoka
# 27178    34      6            Modern        YP3            Koroda
# 27189    34      6            Modern        RO2            Gangza
# 27202    34      6            Modern        VB7            Couple
# 27204    34    NaN               NaN        US2              Locy
# 27207    34      3      Contemporary        YP5             Vonaz
# 27208    34    NaN               NaN        XH6      Authenticity
# 27216    34      6            Modern        UI3            Furama
# 27220    34      3      Contemporary        XN4              Lola
# 27246    34     33               NaN        YP8          A-Monroe
# 27252    34      3      Contemporary        XL5             Commu
# 27262    34     11   Oriental Aspire        YL6            179064
# 27272    34      6            Modern        NaN               NaN
# 27296    34      6            Modern        NaN               NaN
# 27302    34      3      Contemporary        XL5             Commu
# 27318    34     28               NaN        YK5             Saina
# 27330    34      3      Contemporary        YP5             Vonaz
# 27336    34     34               NaN        YP8          A-Monroe
# 27383    34      6            Modern        YD5        686501-617
# 27442    34      3      Contemporary        NZ1              Yono
# 27455    34      6            Modern        NaN               NaN
# 27463    34      7       Modern Chic        YR5             Liden
# 27476    34      3      Contemporary        VE5             Guest
# 27478    34     11   Oriental Aspire        YU1           Sananly
# 27527    34    NaN               NaN        YT7             Hemal
# 27533    34    NaN               NaN        VA1            Zabomb
# 27534    34    NaN               NaN        VA1            Zabomb
# 27549    34    NaN               NaN        YT6             Hanly
# 27571    34    NaN               NaN        ST3           Rebecca
#
#             Model_T Node_Color Color Color_T Node_Cat2  \
# 12              NaN         34  GREY     เทา        60
# 15              NaN         34  GREY     เทา        58
# 18              NaN         34  GREY     เทา        58
# 19              NaN         34  GREY     เทา        58
# 30              NaN         34  GREY     เทา        57
# 32              NaN         34  GREY     เทา        AU
# 133             NaN         34  GREY     เทา        68
# 138             NaN         34  GREY     เทา        62
# 187             NaN         34  GREY     เทา        C6
# 188             NaN         34  GREY     เทา        64
# 193             NaN         34  GREY     เทา        E0
# 233             NaN         34  GREY     เทา        67
# 276             NaN         34  GREY     เทา        B1
# 293             NaN         34  GREY     เทา        D3
# 329             NaN         34  GREY     เทา        E4
# 348         เอเบิ้ล         34  GREY     เทา        K4
# 349             NaN         34  GREY     เทา        90
# 359             NaN         34  GREY     เทา        29
# 364             NaN         34  GREY     เทา        70
# 461             NaN         34  GREY     เทา        88
# 469             NaN         34  GREY     เทา        D4
# 606             NaN         34  GREY     เทา        59
# 610             NaN         34  GREY     เทา        B5
# 619             NaN         34  GREY     เทา        J8
# 628             NaN         34  GREY     เทา        B4
# 683          เอลโม่         34  GREY     เทา        E2
# 764             NaN         34  GREY     เทา        83
# 808             NaN         34  GREY     เทา        J8
# 830             NaN         34  GREY     เทา        J8
# 864             NaN         34  GREY     เทา        J8
# ...             ...        ...   ...     ...       ...
# 27136       Dogwood         34  GREY     เทา        C6
# 27163      ฟูกุโอกะ         34  GREY     เทา        A6
# 27178       โคโรด้า         34  GREY     เทา        58
# 27189     แก๊งค์ซ่า         34  GREY     เทา        64
# 27202       คูเปอร์         34  GREY     เทา        62
# 27204         โลซี่         34  GREY     เทา        59
# 27207         โวนาส         34  GREY     เทา        64
# 27208  Authenticity         34  GREY     เทา        32
# 27216       ฟูราม่า         34  GREY     เทา        62
# 27220          โลลา         34  GREY     เทา        62
# 27246    เอ-มอนโรว์         34  GREY     เทา        59
# 27252         คอมมู         34  GREY     เทา        64
# 27262        179064         34  GREY     เทา        H0
# 27272           NaN         34  GREY     เทา        59
# 27296           NaN         34  GREY     เทา        68
# 27302         คอมมู         34  GREY     เทา        62
# 27318          ไซนา         34  GREY     เทา        86
# 27330         โวนาส         34  GREY     เทา        62
# 27336    เอ-มอนโรว์         34  GREY     เทา        58
# 27383    686501-617         34  GREY     เทา        59
# 27442           NaN         34  GREY     เทา        67
# 27455           NaN         34  GREY     เทา        L5
# 27463       ลินเด้น         34  GREY     เทา        62
# 27476          เกรส         34  GREY     เทา        58
# 27478      ซานานตี้         34  GREY     เทา        62
# 27527         ฮีเมล         34  GREY     เทา        62
# 27533         ซาบอม         34  GREY     เทา        15
# 27534         ซาบอม         34  GREY     เทา        17
# 27549        เฮนรี่         34  GREY     เทา        59
# 27571      รีเบกก้า         34  GREY     เทา        61
#
#                                  Cat2                               LTEXT_T
# 12                     โซฟา 4 ที่นั่ง                                   NaN
# 15                     โซฟา 2 ที่นั่ง                                   NaN
# 18                     โซฟา 2 ที่นั่ง                                   NaN
# 19                     โซฟา 2 ที่นั่ง                                   NaN
# 30                     โซฟา 1 ที่นั่ง                                   NaN
# 32                       อาร์มแชร์ผ้า                                   NaN
# 133                           โซฟาเบด                                   NaN
# 138                    โซฟาเข้ามุมขวา                                   NaN
# 187                            คอนโซล                                   NaN
# 188                   โซฟาเข้ามุมซ้าย                                   NaN
# 193                   ตู้โชว์+วางทีวี                                   NaN
# 233    โซฟาเข้ามุมสลับด้านได้ซ้าย/ขวา                                   NaN
# 276                         ไซด์บอร์ด                                   NaN
# 293                   ตู้เตี้ยลิ้นชัก                                   NaN
# 329                            ตู้สูง                                   NaN
# 348                   สินค้าเบ็ดเตล็ด                                   NaN
# 349                   โต๊ะข้างไม้ล้วน                                   NaN
# 359              เก้าอี้เหล็กเบาะหนัง                                   NaN
# 364                      ตู้ข้างเตียง                                   NaN
# 461              โต๊ะข้างไม้ท๊อปกระจก                                   NaN
# 469                ตู้เสื้อผ้าบานเปิด                                   NaN
# 606                    โซฟา 3 ที่นั่ง                                   NaN
# 610                      กระจกแบบแขวน                                   NaN
# 619                   ของตกแต่งอื่น ๆ                                   NaN
# 628                           กรอบรูป                                   NaN
# 683                        ตู้รองเท้า                                   NaN
# 764              โต๊ะข้างเหล็กท๊อปไม้                                   NaN
# 808                   ของตกแต่งอื่น ๆ                                   NaN
# 830                   ของตกแต่งอื่น ๆ                                   NaN
# 864                   ของตกแต่งอื่น ๆ                                   NaN
# ...                               ...                                   ...
# 27136                          คอนโซล                                   NaN
# 27163         โต๊ะอาหารขาเหล็กท๊อปหิน  Dining Table/Steel/Natural Stone Top
# 27178                  โซฟา 2 ที่นั่ง                                   NaN
# 27189                 โซฟาเข้ามุมซ้าย                                   NaN
# 27202                  โซฟาเข้ามุมขวา                                   NaN
# 27204                  โซฟา 3 ที่นั่ง                                   NaN
# 27207                 โซฟาเข้ามุมซ้าย                                   NaN
# 27208               เก้าอี้ไม้เบาะผ้า                                   NaN
# 27216                  โซฟาเข้ามุมขวา                                   NaN
# 27220                  โซฟาเข้ามุมขวา                                   NaN
# 27246                  โซฟา 3 ที่นั่ง                                   NaN
# 27252                 โซฟาเข้ามุมซ้าย                                   NaN
# 27262                            สตูล                                   NaN
# 27272                  โซฟา 3 ที่นั่ง                                   NaN
# 27296                         โซฟาเบด                                   NaN
# 27302                  โซฟาเข้ามุมขวา                                   NaN
# 27318               โต๊ะข้างเหล็กล้วน                                   NaN
# 27330                  โซฟาเข้ามุมขวา                                   NaN
# 27336                  โซฟา 2 ที่นั่ง                                   NaN
# 27383                  โซฟา 3 ที่นั่ง                                   NaN
# 27442  โซฟาเข้ามุมสลับด้านได้ซ้าย/ขวา                                   NaN
# 27455                  ที่คั่นหนังสือ                                   NaN
# 27463                  โซฟาเข้ามุมขวา                                   NaN
# 27476                  โซฟา 2 ที่นั่ง                                   NaN
# 27478                  โซฟาเข้ามุมขวา                                   NaN
# 27527                  โซฟาเข้ามุมขวา                                   NaN
# 27533        เก้าอี้พักผ่อน 1 ที่นั่ง                                   NaN
# 27534        เก้าอี้พักผ่อน 3 ที่นั่ง                                   NaN
# 27549                  โซฟา 3 ที่นั่ง                                   NaN
# 27571                      โซฟาสั่งทำ                                   NaN
#
# [1338 rows x 16 columns]

# %% [markdown]
# # Normalize

# %%
from sklearn import preprocessing
from sklearn.preprocessing import normalize

color_id_norm = df_product_id[['Color_id']].values
min_max_scaler = preprocessing.MinMaxScaler()
color_scaled = min_max_scaler.fit_transform(color_id_norm)
df_color_norm = pd.DataFrame(color_scaled, columns=['Color_id_n'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
sty_id_norm = df_product_id[['Style_id']].values
min_max_scaler = preprocessing.MinMaxScaler()
sty_scaled = min_max_scaler.fit_transform(sty_id_norm)
df_sty_norm = pd.DataFrame(sty_scaled, columns=['Style_id_n'])

cat2_id_norm = df_product_id[['Cat2_id']].values
min_max_scaler = preprocessing.MinMaxScaler()
cat2_scaled = min_max_scaler.fit_transform(cat2_id_norm)
df_cat2_norm = pd.DataFrame(cat2_scaled, columns=['Cat2_id_n'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
df_product_id_n = pd.concat([df_product_id, df_color_norm, df_sty_norm, df_cat2_norm], axis=1)
df_product_id_n.drop(df_product_id_n.columns[[5,6,7,8]], axis=1, inplace = True)

# %%
df_product_id_n
# Out:
#           MATNR     Model         Color             Style  \
# 0      19047936   Patisia         White           Vintage
# 1      19045101   Cannery        Yellow            Modern
# 2      19050282     zNone  Multi-Colour           Vintage
# 3      59000365    Meudon         Black      Contemporary
# 4      59001810    Alicia         White            Modern
# 5      19049900   Santana         White            Modern
# 6      19040929     Bella         Brown    Modern Italian
# 7      19045046      Jovi         Black            Modern
# 8      19045211    Grazia    Brown Dark      Contemporary
# 9      59000343    Koloze    Brown Dark            Modern
# 10     19042680    Kokoro        Purple      Contemporary
# 11     19050326    Levonn         White  Luxury Glamorous
# 12     19050327   Latanya          Grey  Luxury Glamorous
# 13     19042726      Ives        Purple            Modern
# 14     19045832     Maxio         White    Modern Italian
# 15     19050328   Latanya          Grey  Luxury Glamorous
# 16     19050345     Yitta          Grey  Luxury Glamorous
# 17     19047934   Patisia         White           Vintage
# 18     19049891    Kabira          Grey    Modern Classic
# 19     19050324    Leewan          Grey  Luxury Glamorous
# 20     19050325    Levonn         White  Luxury Glamorous
# 21     19045031    Mamara         Brown            Modern
# 22     19045032    Mamara        Yellow            Modern
# 23     19035030      Exio         Black    Modern Italian
# 24     19042705    Angela        Yellow       Modern Chic
# 25     19046676      Coco           Red            Modern
# 26     19049870  Terminus    Brown Dark            Modern
# 27     19049871  Terminus    Brown Dark            Modern
# 28     59000712   Jocasta         White    Modern Classic
# 29     59000614    Hybrid         zNone      Contemporary
# ...         ...       ...           ...               ...
# 27542  19138746   A-Sonia         Brown             zNone
# 27543  19139148   Espanso         Brown             zNone
# 27544  19132025    Trixie   Brown Light            Modern
# 27545  19132830   Restrol         Black            Modern
# 27546  19134126      0529         zNone            Modern
# 27547  19134146      0529         zNone            Modern
# 27548  19134382      0530         zNone            Modern
# 27549  19140271     Hanly          Grey             zNone
# 27550  19140411    Xantic         Brown             zNone
# 27551  19140588     Dante         Brown             zNone
# 27552  19140589     Dante         Brown             zNone
# 27553  19140590     Dante         Black             zNone
# 27554  19140591     Dante         Brown             zNone
# 27555  19125474   Finetti         zNone            Modern
# 27556  19135987     Lacee         Brown      Contemporary
# 27557  19131725       Tag         Brown      Contemporary
# 27558  19135988     Lacee         Green      Contemporary
# 27559  19136286     Earra         Black             zNone
# 27560  19136287    Effect         Black             zNone
# 27561  19136288     Econo         Black             zNone
# 27562  19136289     Enema         Black             zNone
# 27563  19134398      0530         zNone            Modern
# 27564  19134406      0530         zNone            Modern
# 27565  19134454      0530         zNone            Modern
# 27566  19140598   Rebecca        Yellow             zNone
# 27567  19140896    Mirada         Green             zNone
# 27568  19141036   Rebecca        Yellow             zNone
# 27569  19141037   Rebecca         Green             zNone
# 27570  19141038   Rebecca        Purple             zNone
# 27571  19141039   Rebecca          Grey             zNone
#
#                           Cat2  Color_id_n  Style_id_n  Cat2_id_n
# 0                 ตู้ข้างเตียง    0.003467    0.005308   0.013143
# 1               โซฟา 3 ที่นั่ง    0.003699    0.002539   0.044250
# 2                      กรอบรูป    0.002080    0.005308   0.000876
# 3                   ชุดห้องนอน    0.000000    0.000923   0.010953
# 4                   ชุดห้องนอน    0.003467    0.002539   0.010953
# 5               โซฟาเข้ามุมขวา    0.003467    0.002539   0.045126
# 6               โซฟา 3 ที่นั่ง    0.000462    0.003462   0.044250
# 7               โซฟา 4 ที่นั่ง    0.000000    0.002539   0.044469
# 8                        เตียง    0.000693    0.000923   0.041183
# 9                        zNone    0.000693    0.002539   1.000000
# 10              โซฟา 3 ที่นั่ง    0.003005    0.000923   0.044250
# 11              โซฟา 2 ที่นั่ง    0.003467    0.002077   0.044031
# 12              โซฟา 4 ที่นั่ง    0.001849    0.002077   0.044469
# 13                     โซฟาเบด    0.003005    0.002539   0.046440
# 14                       เตียง    0.003467    0.003462   0.041183
# 15              โซฟา 2 ที่นั่ง    0.001849    0.002077   0.044031
# 16                     ตู้โชว์    0.001849    0.002077   0.015991
# 17                     ตู้โชว์    0.003467    0.005308   0.015991
# 18              โซฟา 2 ที่นั่ง    0.001849    0.003000   0.044031
# 19              โซฟา 2 ที่นั่ง    0.001849    0.002077   0.044031
# 20              โซฟา 4 ที่นั่ง    0.003467    0.002077   0.044469
# 21             โซฟาเข้ามุมซ้าย    0.000462    0.002539   0.045564
# 22             โซฟาเข้ามุมซ้าย    0.003699    0.002539   0.045564
# 23        ตู้เสื้อผ้าบานเฟี้ยม    0.000000    0.003462   0.014896
# 24              โซฟา 3 ที่นั่ง    0.003699    0.002769   0.044250
# 25              โซฟา 2 ที่นั่ง    0.003236    0.002539   0.044031
# 26                      ตู้สูง    0.000693    0.002539   0.013801
# 27                   ไซด์บอร์ด    0.000693    0.002539   0.056079
# 28            โต๊ะอาหารไม้ล้วน    0.003467    0.003000   0.054765
# 29                       zNone    1.000000    0.000923   1.000000
# ...                        ...         ...         ...        ...
# 27542           โซฟา 3 ที่นั่ง    0.000462    1.000000   0.044250
# 27543           โซฟา 3 ที่นั่ง    0.000462    1.000000   0.044250
# 27544           เคาน์เตอร์บาร์    0.000925    0.002539   0.040307
# 27545  โต๊ะอาหารขาเหล็กท๊อปไม้    0.000000    0.002539   0.053231
# 27546               โซฟาสั่งทำ    1.000000    0.002539   0.044907
# 27547               โซฟาสั่งทำ    1.000000    0.002539   0.044907
# 27548               โซฟาสั่งทำ    1.000000    0.002539   0.044907
# 27549           โซฟา 3 ที่นั่ง    0.001849    1.000000   0.044250
# 27550  โต๊ะอาหารขาเหล็กท๊อปไม้    0.000462    1.000000   0.053231
# 27551                  ตู้โชว์    0.000462    1.000000   0.015991
# 27552                ไซด์บอร์ด    0.000462    1.000000   0.056079
# 27553             ตู้ข้างเตียง    0.000000    1.000000   0.013143
# 27554                ไซด์บอร์ด    0.000462    1.000000   0.056079
# 27555                    เตียง    1.000000    0.002539   0.041183
# 27556         โต๊ะอาหารไม้ล้วน    0.000462    0.000923   0.054765
# 27557          โซฟาเข้ามุมซ้าย    0.000462    0.000923   0.045564
# 27558      เก้าอี้เหล็กเบาะผ้า    0.001618    0.000923   0.037678
# 27559                   ตู้สูง    0.000000    1.000000   0.013801
# 27560                 ชั้นโล่ง    0.000000    1.000000   0.007667
# 27561                 ชั้นโล่ง    0.000000    1.000000   0.007667
# 27562                 ชั้นโล่ง    0.000000    1.000000   0.007667
# 27563               โซฟาสั่งทำ    1.000000    0.002539   0.044907
# 27564               โซฟาสั่งทำ    1.000000    0.002539   0.044907
# 27565               โซฟาสั่งทำ    1.000000    0.002539   0.044907
# 27566           โซฟา 2 ที่นั่ง    0.003699    1.000000   0.044031
# 27567             อาร์มแชร์ผ้า    0.001618    1.000000   0.031106
# 27568               โซฟาสั่งทำ    0.003699    1.000000   0.044907
# 27569               โซฟาสั่งทำ    0.001618    1.000000   0.044907
# 27570               โซฟาสั่งทำ    0.003005    1.000000   0.044907
# 27571               โซฟาสั่งทำ    0.001849    1.000000   0.044907
#
# [27572 rows x 8 columns]

# %%
from sklearn.neighbors import NearestNeighbors

input_item = 19132830
input_index = df_product_id_n.index[df_product_id_n['MATNR'] == input_item].tolist()[0]
call_frame = df_product_id_n.loc[(df_product_id_n.MATNR.isin([input_item])), ['Color_id_n', 'Style_id_n', 'Cat2_id_n']]
item = call_frame.values

product = df_product_id_n.iloc[:,5:8].values
nbrs = NearestNeighbors(n_neighbors=11).fit(product)
nbrs_res = nbrs.kneighbors([item[0]])[1]
nbrs_list = nbrs_res.tolist()[0]
while input_index in nbrs_list: nbrs_list.remove(input_index)
result = nbrs_list
#print(result)
df_product_id_n.ilococ[result]
# Out:
#           MATNR    Model  Color   Style                     Cat2  Color_id_n  \
# 12177  19080279    Coupe  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 22915  19117034  Restrol  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 18045  59008084     Hana  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 23021  59012842   Anakin  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 7626   19090106   Anakin  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 19335  19111488     Zoki  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 27515  19097478   Berska  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 20116  59012554  Restrol  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 19306  59011377     Zoki  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
# 19876  59012560     Zoki  Black  Modern  โต๊ะอาหารขาเหล็กท๊อปไม้         0.0
#
#        Style_id_n  Cat2_id_n
# 12177    0.002539   0.053231
# 22915    0.002539   0.053231
# 18045    0.002539   0.053231
# 23021    0.002539   0.053231
# 7626     0.002539   0.053231
# 19335    0.002539   0.053231
# 27515    0.002539   0.053231
# 20116    0.002539   0.053231
# 19306    0.002539   0.053231
# 19876    0.002539   0.053231
